# %% [markdown]
# ## Rahel Ghebrekidan
# ## Project 3 - Data Wrangling with MongoDB
# ## Nanodegree Data Analyst
# ## Udacity

# %% [markdown]
# ### Data: July 22, 2016

# %% [markdown]
# # Open Street Map - Santa Monica, California

# %% [markdown]
# # Parsing XML file

# %%
% cd 'C:\Users\Rahel G G\Udacity\Project_3'
# Out:
# C:\Users\Rahel G G\Udacity\Project_3

# %%
#Parsing xml file
import xml.etree.ElementTree as ET
import pprint
import os
SM_data= "Santa_Monica.osm"
def count_tags(filename):
        tags = {}
        for event, elem in ET.iterparse(filename):
            if elem.tag in tags: 
                tags[elem.tag] += 1
            else:
                tags[elem.tag] = 1
        return tags
SM_tags = count_tags(SM_data)
pprint.pprint(SM_tags)
# Out:
# {'bounds': 1,
#  'member': 4167,
#  'nd': 544106,
#  'node': 486074,
#  'osm': 1,
#  'relation': 792,
#  'tag': 320481,
#  'way': 51875}

# %% [markdown]
# ### Volunteers involved in this map editing

# %%
def process_map(filename):
    users = set()
    for _, element in ET.iterparse(filename):
        for e in element:
            if 'uid' in e.attrib:
                users.add(e.attrib['uid'])
    return users
users = process_map(SM_data)
len(users)
# Out:
# 351

# %% [markdown]
# #### Checking  lowercase(lower-colon), with colon in their names(lower-colon) and tags with problematic characters(Problemchars)

# %%
import re

lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')


def key_type(element, keys):
    if element.tag == "tag":
        for tag in element.iter('tag'):
            k = tag.get('k')
            if lower.search(k):
                keys['lower'] += 1
            elif lower_colon.search(k):
                keys['lower_colon'] += 1
            elif problemchars.search(k):
                keys['problemchars'] += 1
            else:
                keys['other'] += 1
    return keys


def process_map(filename):
    keys = {"lower": 0, "lower_colon": 0, "problemchars": 0, "other": 0}
    for _, element in ET.iterparse(filename):
        keys = key_type(element, keys)

    return keys

cal_keys = process_map(SM_data)
pprint.pprint(cal_keys)
# Out:
# {'lower': 184178, 'lower_colon': 134423, 'other': 1879, 'problemchars': 1}

# %% [markdown]
# ##  Problem Encountering
#
# I will check if there are problem with Street names(using abbreviations) and with the zip codes.
#
#
# ###  Street address
#
# Below are mentioned street names expected and abbrevations.

# %%
from collections import defaultdict

street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE) 

expected = ["Avenue", "Boulevard", "Commons", "Court", "Drive", "Lane", "Parkway","Access","Highway", "Walk", 
                         "Place", "Road", "Square", "Street", "Trail", "Way", "access", 
                          "Center", "access", "1101", "1180","Pico", "North", "Marina","Promenada","Broadway" ]

mapping = {'Ave'  : 'Avenue',
           'Blvd' : 'Boulevard',
           'Blvd.': "Boulevard",
           'Bd.'  : 'Boulevard',
           'Bvd'  : 'Boulevard',
           'Bvd.' : 'Boulevard',
           'Dr'   : 'Drive',
           'Ln'   : 'Lane',
           'Pkwy' : 'Parkway',
           'Rd'   : 'Road',
           'Rd.'  : 'Road',
           'St.'   : 'Street',
           'Ct'   : "Court",
           'Cir'  : "Circle",
           'Cr'   : "Court",
           'ave'  : 'Avenue',
           'Hwg'  : 'Highway',
           'Hwy'  : 'Highway',
           'Sq'   : "Square",
           'St.'  : "Street"}

# %% [markdown]
# #### Matching the street names in the data with the above abbreviations and expected names

# %%
def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)

def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")

def audit(osmfile):
    osm_file = open(osmfile, "r")
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])

    return street_types

# %%
cal_street_types = audit(SM_data)

# %% [markdown]
# #### Printing Streets with problem

# %%
pprint.pprint(dict(cal_street_types))
# Out:
# {'Ave': set(['Montana Ave', 'Ohio Ave', 'Olive Ave']),
#  'Bd.': set(['Ocean Bd.']),
#  'Blvd': set(['Lincoln Blvd',
#               'Pico Blvd',
#               'Santa Monica Blvd',
#               'W Pico Blvd',
#               'W Washington Blvd',
#               'Washington Blvd',
#               'Wilshire Blvd',
#               'Wishire Blvd']),
#  'Blvd.': set(['Olympic Blvd.']),
#  'Bvd': set(['Santa Monica Bvd']),
#  'Dr': set(['Entrada Dr']),
#  'Ln': set(['Walnut Ln']),
#  'Promenade': set(['Third Street Promenade']),
#  'South': set(['Donald Douglas Loop South']),
#  'St.': set(['Main St.']),
#  'ave': set(['Olive ave'])}

# %% [markdown]
# #### Replacing the Street names with problem

# %%
def update_street(name, mapping, regex):
    m = regex.search(name)
    if m:
        street_type = m.group()
        if street_type in mapping:
            name = re.sub(regex, mapping[street_type], name)

        return name

for street_type, ways in cal_street_types.iteritems():
    for name in ways:
        better_name = update_street(name, mapping, street_type_re)
        print name, "=>", better_name
# Out:
# Walnut Ln => Walnut Lane
# Main St. => Main Street
# Ocean Bd. => Ocean Boulevard
# Olive Ave => Olive Avenue
# Ohio Ave => Ohio Avenue
# Montana Ave => Montana Avenue
# Third Street Promenade => Third Street Promenade
# Santa Monica Bvd => Santa Monica Boulevard
# Pico Blvd => Pico Boulevard
# Lincoln Blvd => Lincoln Boulevard
# Wishire Blvd => Wishire Boulevard
# W Washington Blvd => W Washington Boulevard
# Wilshire Blvd => Wilshire Boulevard
# W Pico Blvd => W Pico Boulevard
# Washington Blvd => Washington Boulevard
# Santa Monica Blvd => Santa Monica Boulevard
# Olive ave => Olive Avenue
# Entrada Dr => Entrada Drive
# Donald Douglas Loop South => Donald Douglas Loop South
# Olympic Blvd. => Olympic Boulevard

# %% [markdown]
# ####  Zip codes

# %%
from collections import defaultdict
# Zipcodes exceeding or less than 5 digits and with prefix are invalid
def audit_zipcode(invalid_zipcodes, zipcode):
    valid_zipcodes = re.match(r'^[0-9]{5}$', zipcode)
    if not valid_zipcodes:
                   invalid_zipcodes[valid_zipcodes].add(zipcode)
        
def is_zipcode(elem):
    return (elem.attrib['k'] == "addr:postcode")

def audit_zip(osmfile):
    osm_file = open(osmfile, "r")
    invalid_zipcodes = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_zipcode(tag):
                    audit_zipcode(invalid_zipcodes,tag.attrib['v'])

    return invalid_zipcodes

audit_zipcode = audit_zip(SM_data)

# %%
pprint.pprint(dict(audit_zipcode))
# Out:
# {None: set(['90025-9998',
#             '90064-1508',
#             '90272-3719',
#             '90291-3879',
#             '90401-2405',
#             'CA 90272',
#             'CA 90291',
#             'CA 90401',
#             'CA 90404',
#             'CA 90405'])}

# %% [markdown]
# #### Updating Postcodes

# %%
def update_zipcode(zipcode):
    # Deleting the digits and the hyphen after the fifth digit and the prefix "CA"
    Ext_check = re.findall('(\d{5})-\d{4}', zipcode)
    if Ext_check:
        return re.sub('(\d{5})-\d{4}', '\\1', zipcode) 
    else:
        return re.sub('[^0-9]', '', zipcode)[:5]
for zipcodes, ways in audit_zipcode.iteritems():
    for zipcode in ways:
        better_zipcode = update_zipcode(zipcode)
        print zipcode, "=>", better_zipcode
# Out:
# 90025-9998 => 90025
# CA 90291 => 90291
# 90401-2405 => 90401
# CA 90272 => 90272
# CA 90404 => 90404
# 90272-3719 => 90272
# CA 90401 => 90401
# CA 90405 => 90405
# 90064-1508 => 90064
# 90291-3879 => 90291

# %% [markdown]
# ##  Phone Numbers

# %%
from collections import defaultdict

def audit_phone_number(invalid_phone_numbers, phone_number):
    #telephone numbers with more than 11 digits and separated by dot are considered invalid
    valid_phone_numbers = re.match(r'^(?:(?:\+?1\s*(?:[-]\s*)?)?(?:\(\s*([2-9]1[02-9]|[2-9][02-8]1|[2-9][02-8][02-9])\s*\)|([2-9]1[02-9]|[2-9][02-8]1|[2-9][02-8][02-9]))\s*(?:[-]\s*)?)?([2-9]1[02-9]|[2-9][02-9]1|[2-9][02-9]{2})\s*(?:[-]\s*)?([0-9]{4})(?:\s*(?:#|x\.?|ext\.?|extension)\s*(\d+))?$', phone_number)
  
    if not valid_phone_numbers:
                   invalid_phone_numbers[valid_phone_numbers].add(phone_number)
        
def is_phone_number(elem):
    return (elem.attrib['k'] == "phone")

def audit_phone_num(osmfile):
    osm_file = open(osmfile, "r")
    invalid_phone_numbers = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_phone_number(tag):
                    audit_phone_number(invalid_phone_numbers,tag.attrib['v'])

    return invalid_phone_numbers

audit_phone_number = audit_phone_num(SM_data)

# %%
pprint.pprint(dict(audit_phone_number))
# Out:
# {None: set(['+01-310-260-6308',
#             '310. 444. 0045',
#             '310.473.1447',
#             '310.478.3545',
#             '310.826.2229'])}

# %%
def update_phone(phone_number):
    valid_phone = re.sub('[^0-9]+', '', phone_number)
    phone_pattern = re.sub("(\d)(?=(\d{3})+(?!\d))", r"\1-", "%d" % int(valid_phone[:-1])) + valid_phone[-1]
    return phone_pattern
for phone_number, ways in audit_phone_number.iteritems():
    for phone in ways:
        better_phone_num = update_phone(phone)
        print phone, "=>", better_phone_num
# Out:
# +01-310-260-6308 => 1-310-260-6308
# 310. 444. 0045 => 310-444-0045
# 310.473.1447 => 310-473-1447
# 310.478.3545 => 310-478-3545
# 310.826.2229 => 310-826-2229

# %% [markdown]
# ## Converting XML to JSON format
#
# Inorder to be readable on Mongodb, the XML formate should be changed to JSON format

# %%
import re
import codecs 
import json

lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

CREATED = [ "version", "changeset", "timestamp", "user", "uid"]


def shape_element(element):
    node = {}
    # processing nodes and ways
    if element.tag == "node" or element.tag == "way" :
        for key in element.attrib.keys():
            val = element.attrib[key]
            node["type"] = element.tag
            if key in CREATED:
                if not "created" in node.keys():
                    node["created"] = {}
                node["created"][key] = val
            elif key == "lat" or key == "lon":
                if not "pos" in node.keys():
                    node["pos"] = [0.0, 0.0]
                old_pos = node["pos"]
                if key == "lat":
                    new_pos = [float(val), old_pos[1]]
                else:
                    new_pos = [old_pos[0], float(val)]
                node["pos"] = new_pos
            else:
                node[key] = val
        #itering child element
        for child in element. iter("tag"):
            if not problemchars.search(child.attrib['k']):
                if lower_colon.search(child.attrib['k']):
                    if child.attrib['k'].find('addr') == 0:
                    
                        if 'address' not in node:
                            node['address'] = {}
                        sub_attr = child.attrib['k'].split(':')
                        node['address'][sub_attr[0]] = child.attrib['v']
                        address = node['address']
                        sub_key = sub_attr[1]
                        #updating street
                        if sub_key == 'street':
                            address['street'] = update_street(child.attrib['v'], mapping, street_type_re)
                        #updating zipcode
                        elif sub_key == 'postcode':
                            address['postcode'] = update_zipcode(child.attrib['v'])
                        else:
                            address[sub_key] = child.attrib['v']
                    else:
                        node[child.attrib['k']] = child.attrib['v']
                elif child.attrib['k'].find(':') == -1:
                    node[child.attrib['k']] = child.attrib['v']
                    key_itm = child.attrib['k']
                    #updating telephone number
                    if key_itm == 'phone':
                        node['phone'] = update_phone(child.attrib['v'])
                
        for nd in element.iter("nd"):
            if 'node_refs' not in node:
                node['node_refs'] = []
            node['node_refs'].append(nd.attrib['ref'])

        return node
    else:
        return None


def process_map(file_in, pretty = False):
    file_out = "{0}.json".format(file_in)
    data = []
    with codecs.open(file_out, "w") as fo:
        for _, element in ET.iterparse(file_in):
            el = shape_element(element)
            if el:
                data.append(el)
                if pretty:
                    fo.write(json.dumps(el, indent=2)+"\n")
                else:
                    fo.write(json.dumps(el) + "\n")
    return data
process_map(SM_data, False)
# Out:
# [{'created': {'changeset': '11239147',
#    'timestamp': '2012-04-09T15:23:25Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '21'},
#   'id': '14752647',
#   'pos': [34.0278652, -118.4512786],
#   'type': 'node'},
#  {'created': {'changeset': '11245718',
#    'timestamp': '2012-04-09T22:09:46Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '20'},
#   'id': '14752649',
#   'pos': [34.0230505, -118.4746697],
#   'type': 'node'},
#  {'created': {'changeset': '3784290',
#    'timestamp': '2010-02-03T16:55:09Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '3'},
#   'id': '15857078',
#   'pos': [34.0288171, -118.4506263],
#   'type': 'node'},
#  {'created': {'changeset': '3784290',
#    'timestamp': '2010-02-03T16:55:09Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '3'},
#   'id': '15857079',
#   'pos': [34.0289905, -118.4503527],
#   'type': 'node'},
#  {'created': {'changeset': '10561877',
#    'timestamp': '2012-02-01T19:53:49Z',
#    'uid': '207745',
#    'user': 'NE2',
#    'version': '6'},
#   'id': '15857080',
#   'pos': [34.0285813, -118.4495582],
#   'type': 'node'},
#  {'created': {'changeset': '11277124',
#    'timestamp': '2012-04-12T14:33:39Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '4'},
#   'id': '15857081',
#   'pos': [34.0278797, -118.4490024],
#   'type': 'node'},
#  {'created': {'changeset': '37255385',
#    'timestamp': '2016-02-16T21:13:37Z',
#    'uid': '1829683',
#    'user': 'Luis36995',
#    'version': '4'},
#   'id': '15857085',
#   'pos': [34.0214893, -118.4450928],
#   'type': 'node'},
#  {'created': {'changeset': '11268439',
#    'timestamp': '2012-04-11T19:04:27Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '3'},
#   'id': '15857086',
#   'pos': [34.0190655, -118.4448094],
#   'type': 'node'},
#  {'created': {'changeset': '37982743',
#    'timestamp': '2016-03-21T18:24:03Z',
#    'uid': '2748195',
#    'user': 'karitotp',
#    'version': '5'},
#   'id': '15857087',
#   'pos': [34.0176362, -118.4441932],
#   'type': 'node'},
#  {'created': {'changeset': '10552097',
#    'timestamp': '2012-01-31T21:30:10Z',
#    'uid': '207745',
#    'user': 'NE2',
#    'version': '24'},
#   'exit_to': 'Bundy Dr South',
#   'highway': 'motorway_junction',
#   'id': '15857120',
#   'is_in:state_code': 'CA',
#   'pos': [34.0289555, -118.4470546],
#   'ref': '2B',
#   'source': 'usgs_imagery;survey;image',
#   'source_ref': 'AM909_DSCS6353',
#   'type': 'node'},
#  {'created': {'changeset': '11387408',
#    'timestamp': '2012-04-22T18:24:41Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '21'},
#   'id': '18166105',
#   'pos': [33.9941128, -118.4528311],
#   'type': 'node'},
#  {'created': {'changeset': '11239147',
#    'timestamp': '2012-04-09T15:23:18Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '8'},
#   'id': '18166113',
#   'pos': [34.0267693, -118.4556097],
#   'type': 'node'},
#  {'created': {'changeset': '3059147',
#    'timestamp': '2009-11-08T00:20:42Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '11'},
#   'id': '18166116',
#   'pos': [34.0280437, -118.4529206],
#   'type': 'node'},
#  {'created': {'changeset': '37254971',
#    'timestamp': '2016-02-16T20:53:03Z',
#    'uid': '1829683',
#    'user': 'Luis36995',
#    'version': '8'},
#   'id': '18166117',
#   'pos': [34.027142, -118.4520943],
#   'type': 'node'},
#  {'created': {'changeset': '11239147',
#    'timestamp': '2012-04-09T15:23:18Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '14'},
#   'id': '18166123',
#   'pos': [34.0287149, -118.4472004],
#   'type': 'node'},
#  {'created': {'changeset': '15368987',
#    'timestamp': '2013-03-15T03:09:12Z',
#    'uid': '1679',
#    'user': 'andrewpmk',
#    'version': '11'},
#   'highway': 'traffic_signals',
#   'id': '21300202',
#   'pos': [34.0477348, -118.4443465],
#   'type': 'node'},
#  {'created': {'changeset': '345332',
#    'timestamp': '2009-02-11T04:57:09Z',
#    'uid': '36489',
#    'user': 'jerjozwik',
#    'version': '21'},
#   'id': '21302846',
#   'pos': [34.0266561, -118.4615733],
#   'type': 'node'},
#  {'created': {'changeset': '18268754',
#    'timestamp': '2013-10-09T17:33:50Z',
#    'uid': '14293',
#    'user': 'KindredCoda',
#    'version': '3'},
#   'id': '21748307',
#   'pos': [34.0486437, -118.4479654],
#   'type': 'node'},
#  {'created': {'changeset': '6053254',
#    'timestamp': '2010-10-15T23:40:19Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '4'},
#   'id': '24960513',
#   'pos': [33.9943929, -118.4447169],
#   'type': 'node'},
#  {'created': {'changeset': '11389551',
#    'timestamp': '2012-04-22T21:57:44Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '6'},
#   'id': '24960514',
#   'pos': [33.9932655, -118.4488256],
#   'type': 'node'},
#  {'created': {'changeset': '11389551',
#    'timestamp': '2012-04-22T21:57:43Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '11'},
#   'id': '24960515',
#   'pos': [33.9923427, -118.4494641],
#   'type': 'node'},
#  {'created': {'changeset': '12294067',
#    'timestamp': '2012-07-18T19:10:39Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '26426223',
#   'is_in': 'USA, California, Los Angeles',
#   'name': 'Marina del Rey',
#   'place': 'suburb',
#   'pos': [33.9774017, -118.4508018],
#   'type': 'node'},
#  {'created': {'changeset': '27324899',
#    'timestamp': '2014-12-08T01:56:44Z',
#    'uid': '50743',
#    'user': 'dima',
#    'version': '9'},
#   'id': '26427110',
#   'pos': [33.9686202, -118.4446163],
#   'type': 'node'},
#  {'created': {'changeset': '35792367',
#    'timestamp': '2015-12-06T18:47:48Z',
#    'uid': '1427293',
#    'user': 'kingrollo',
#    'version': '3'},
#   'id': '26427111',
#   'pos': [33.968862, -118.44461],
#   'type': 'node'},
#  {'created': {'changeset': '11398509',
#    'timestamp': '2012-04-23T19:27:46Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '4'},
#   'id': '26427112',
#   'pos': [33.9700496, -118.4455769],
#   'type': 'node'},
#  {'created': {'changeset': '36428971',
#    'timestamp': '2016-01-07T17:03:31Z',
#    'uid': '2655992',
#    'user': 'steverumizen',
#    'version': '10'},
#   'highway': 'traffic_signals',
#   'id': '26427678',
#   'pos': [33.9904517, -118.4478247],
#   'traffic_signals': 'signal',
#   'type': 'node'},
#  {'created': {'changeset': '35733704',
#    'timestamp': '2015-12-03T19:17:43Z',
#    'uid': '2655992',
#    'user': 'steverumizen',
#    'version': '7'},
#   'highway': 'traffic_signals',
#   'id': '26427686',
#   'pos': [33.9882028, -118.4521553],
#   'traffic_signals': 'signal',
#   'type': 'node'},
#  {'created': {'changeset': '3070644',
#    'timestamp': '2009-11-09T05:28:05Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '5'},
#   'id': '26427688',
#   'pos': [33.9849148, -118.4574011],
#   'type': 'node'},
#  {'created': {'changeset': '3070644',
#    'timestamp': '2009-11-09T05:22:38Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '4'},
#   'id': '26427693',
#   'pos': [33.9830074, -118.4604309],
#   'type': 'node'},
#  {'created': {'changeset': '3070644',
#    'timestamp': '2009-11-09T05:22:39Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '4'},
#   'id': '26427700',
#   'pos': [33.982068, -118.4618815],
#   'type': 'node'},
#  {'created': {'changeset': '37437819',
#    'timestamp': '2016-02-25T15:14:04Z',
#    'uid': '1829683',
#    'user': 'Luis36995',
#    'version': '5'},
#   'id': '26427710',
#   'pos': [33.9815607, -118.4626726],
#   'type': 'node'},
#  {'created': {'changeset': '3070644',
#    'timestamp': '2009-11-09T05:22:39Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '4'},
#   'id': '26427711',
#   'pos': [33.981036, -118.4635037],
#   'type': 'node'},
#  {'created': {'changeset': '20000848',
#    'timestamp': '2014-01-14T22:22:40Z',
#    'uid': '1883488',
#    'user': 'doublentendre',
#    'version': '5'},
#   'highway': 'traffic_signals',
#   'id': '26427712',
#   'pos': [33.9797445, -118.4656523],
#   'type': 'node'},
#  {'created': {'changeset': '22725838',
#    'timestamp': '2014-06-04T02:09:23Z',
#    'uid': '111529',
#    'user': 'ReinerMeyer',
#    'version': '7'},
#   'id': '26427713',
#   'pos': [33.9790914, -118.4668788],
#   'type': 'node'},
#  {'created': {'changeset': '20551326',
#    'timestamp': '2014-02-14T01:27:08Z',
#    'uid': '69716',
#    'user': 'Circeus',
#    'version': '2'},
#   'id': '26427725',
#   'is_in': 'USA, California, CA, Los Angeles',
#   'name': 'Venice',
#   'place': 'suburb',
#   'pos': [33.995044, -118.4668875],
#   'type': 'node'},
#  {'created': {'changeset': '22666920',
#    'timestamp': '2014-06-01T05:39:30Z',
#    'uid': '111529',
#    'user': 'ReinerMeyer',
#    'version': '5'},
#   'id': '26427780',
#   'pos': [33.9946426, -118.4834526],
#   'type': 'node'},
#  {'created': {'changeset': '2934609',
#    'timestamp': '2009-10-24T06:27:14Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '3'},
#   'id': '26427794',
#   'pos': [34.0196682, -118.5080037],
#   'type': 'node'},
#  {'created': {'changeset': '4046659',
#    'timestamp': '2010-03-06T05:18:04Z',
#    'uid': '82317',
#    'user': 'AM909',
#    'version': '3'},
#   'id': '26427807',
#   'pos': [34.0150729, -118.5010419],
#   'type': 'node'},
#  {'created': {'changeset': '2934609',
#    'timestamp': '2009-10-24T06:27:21Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '3'},
#   'id': '26427821',
#   'pos': [34.0074544, -118.4998004],
#   'type': 'node'},
#  {'created': {'changeset': '12324219',
#    'timestamp': '2012-07-19T12:17:35Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '5'},
#   'id': '26427824',
#   'name': 'Santa Monica Pier',
#   'pos': [34.0091043, -118.4975247],
#   'tourism': 'attraction',
#   'type': 'node',
#   'wheelchair': 'limited'},
#  {'created': {'changeset': '232296',
#    'timestamp': '2007-03-09T05:12:18Z',
#    'uid': '308',
#    'user': 'MichaelCollinson',
#    'version': '1'},
#   'id': '26427834',
#   'pos': [34.0301085, -118.5232954],
#   'type': 'node'},
#  {'created': {'changeset': '232296',
#    'timestamp': '2007-03-09T05:12:19Z',
#    'uid': '308',
#    'user': 'MichaelCollinson',
#    'version': '1'},
#   'id': '26427835',
#   'pos': [34.029824, -118.5228448],
#   'type': 'node'},
#  {'created': {'changeset': '232296',
#    'timestamp': '2007-03-09T05:12:21Z',
#    'uid': '308',
#    'user': 'MichaelCollinson',
#    'version': '1'},
#   'id': '26427836',
#   'pos': [34.0285969, -118.5208278],
#   'type': 'node'},
#  {'created': {'changeset': '232296',
#    'timestamp': '2007-03-09T05:12:22Z',
#    'uid': '308',
#    'user': 'MichaelCollinson',
#    'version': '1'},
#   'id': '26427837',
#   'pos': [34.0284013, -118.5204844],
#   'type': 'node'},
#  {'created': {'changeset': '2856646',
#    'timestamp': '2009-10-15T17:42:07Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '2'},
#   'id': '26427838',
#   'pos': [34.0281904, -118.5200715],
#   'type': 'node'},
#  {'created': {'changeset': '5235827',
#    'timestamp': '2010-07-16T15:58:37Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '3'},
#   'id': '26427839',
#   'pos': [34.028056, -118.51952],
#   'type': 'node'},
#  {'created': {'changeset': '2934609',
#    'timestamp': '2009-10-24T06:27:11Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '3'},
#   'id': '26427840',
#   'pos': [34.0276, -118.5191016],
#   'type': 'node'},
#  {'created': {'changeset': '2934609',
#    'timestamp': '2009-10-24T06:27:11Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '3'},
#   'id': '26427841',
#   'pos': [34.0272728, -118.5187755],
#   'type': 'node'},
#  {'created': {'changeset': '2934609',
#    'timestamp': '2009-10-24T06:27:11Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '3'},
#   'id': '26427842',
#   'pos': [34.0268176, -118.518724],
#   'type': 'node'},
#  {'created': {'changeset': '2934609',
#    'timestamp': '2009-10-24T06:27:11Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '2'},
#   'id': '26427843',
#   'pos': [34.0263384, -118.5180597],
#   'type': 'node'},
#  {'created': {'changeset': '5235827',
#    'timestamp': '2010-07-16T15:58:35Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '4'},
#   'id': '26427844',
#   'pos': [34.0261154, -118.5176853],
#   'type': 'node'},
#  {'created': {'changeset': '5235827',
#    'timestamp': '2010-07-16T15:58:35Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '3'},
#   'id': '26427845',
#   'pos': [34.0254307, -118.5166715],
#   'type': 'node'},
#  {'created': {'changeset': '2934609',
#    'timestamp': '2009-10-24T06:27:12Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '2'},
#   'id': '26427846',
#   'pos': [34.0250224, -118.5161071],
#   'type': 'node'},
#  {'created': {'changeset': '2934609',
#    'timestamp': '2009-10-24T06:27:12Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '2'},
#   'id': '26427847',
#   'pos': [34.024649, -118.5155706],
#   'type': 'node'},
#  {'created': {'changeset': '5235827',
#    'timestamp': '2010-07-16T15:58:35Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '3'},
#   'id': '26427848',
#   'pos': [34.0242281, -118.5148502],
#   'type': 'node'},
#  {'created': {'changeset': '5235827',
#    'timestamp': '2010-07-16T15:58:36Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '3'},
#   'id': '26427849',
#   'pos': [34.0236523, -118.5133992],
#   'type': 'node'},
#  {'created': {'changeset': '2934609',
#    'timestamp': '2009-10-24T06:27:12Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '3'},
#   'id': '26427850',
#   'pos': [34.0235026, -118.513042],
#   'type': 'node'},
#  {'created': {'changeset': '2934609',
#    'timestamp': '2009-10-24T06:27:13Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '3'},
#   'id': '26427851',
#   'pos': [34.0232181, -118.5127244],
#   'type': 'node'},
#  {'created': {'changeset': '2934609',
#    'timestamp': '2009-10-24T06:27:14Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '3'},
#   'id': '26427852',
#   'pos': [34.0228126, -118.5125098],
#   'type': 'node'},
#  {'created': {'changeset': '5235827',
#    'timestamp': '2010-07-16T15:58:36Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '3'},
#   'id': '26427853',
#   'pos': [34.0225675, -118.5122941],
#   'type': 'node'},
#  {'created': {'changeset': '2934609',
#    'timestamp': '2009-10-24T06:27:14Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '3'},
#   'id': '26427854',
#   'pos': [34.0202231, -118.5085873],
#   'type': 'node'},
#  {'created': {'changeset': '2934609',
#    'timestamp': '2009-10-24T06:27:14Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '3'},
#   'id': '26427855',
#   'pos': [34.0207425, -118.5089221],
#   'type': 'node'},
#  {'created': {'changeset': '5523234',
#    'timestamp': '2010-08-18T04:25:53Z',
#    'uid': '82317',
#    'user': 'AM909',
#    'version': '2'},
#   'id': '26427857',
#   'pos': [34.0308167, -118.5249742],
#   'type': 'node'},
#  {'created': {'changeset': '5523234',
#    'timestamp': '2010-08-18T04:26:03Z',
#    'uid': '82317',
#    'user': 'AM909',
#    'version': '2'},
#   'id': '26427858',
#   'pos': [34.0306447, -118.5243235],
#   'type': 'node'},
#  {'created': {'changeset': '5523234',
#    'timestamp': '2010-08-18T04:26:01Z',
#    'uid': '82317',
#    'user': 'AM909',
#    'version': '2'},
#   'id': '26427859',
#   'pos': [34.0302377, -118.5236195],
#   'type': 'node'},
#  {'created': {'changeset': '5523234',
#    'timestamp': '2010-08-18T04:26:02Z',
#    'uid': '82317',
#    'user': 'AM909',
#    'version': '2'},
#   'id': '26427860',
#   'pos': [34.0308085, -118.5252694],
#   'type': 'node'},
#  {'created': {'changeset': '232296',
#    'timestamp': '2007-03-09T05:23:08Z',
#    'uid': '308',
#    'user': 'MichaelCollinson',
#    'version': '1'},
#   'created_by': 'YahooApplet 1.0',
#   'id': '26427861',
#   'is_in': 'USA, California, CA, Los Angeles',
#   'name': 'Pacific Palisades',
#   'place': 'suburb',
#   'pos': [34.0424134, -118.5409551],
#   'type': 'node'},
#  {'created': {'changeset': '232296',
#    'timestamp': '2007-03-09T05:16:31Z',
#    'uid': '308',
#    'user': 'MichaelCollinson',
#    'version': '1'},
#   'id': '26427862',
#   'pos': [34.0317267, -118.5277157],
#   'type': 'node'},
#  {'created': {'changeset': '5523234',
#    'timestamp': '2010-08-18T04:25:57Z',
#    'uid': '82317',
#    'user': 'AM909',
#    'version': '2'},
#   'id': '26427863',
#   'pos': [34.0335822, -118.5321932],
#   'type': 'node'},
#  {'created': {'changeset': '5523234',
#    'timestamp': '2010-08-18T04:25:58Z',
#    'uid': '82317',
#    'user': 'AM909',
#    'version': '2'},
#   'id': '26427864',
#   'pos': [34.0347877, -118.5350152],
#   'type': 'node'},
#  {'created': {'changeset': '5523234',
#    'timestamp': '2010-08-18T04:25:56Z',
#    'uid': '82317',
#    'user': 'AM909',
#    'version': '2'},
#   'id': '26427865',
#   'pos': [34.0354704, -118.5361689],
#   'type': 'node'},
#  {'created': {'changeset': '5523234',
#    'timestamp': '2010-08-18T04:25:54Z',
#    'uid': '82317',
#    'user': 'AM909',
#    'version': '2'},
#   'id': '26427866',
#   'pos': [34.0369809, -118.5391399],
#   'type': 'node'},
#  {'created': {'changeset': '5523234',
#    'timestamp': '2010-08-18T04:26:03Z',
#    'uid': '82317',
#    'user': 'AM909',
#    'version': '2'},
#   'id': '26427867',
#   'pos': [34.0372736, -118.5396548],
#   'type': 'node'},
#  {'created': {'changeset': '5523234',
#    'timestamp': '2010-08-18T04:26:01Z',
#    'uid': '82317',
#    'user': 'AM909',
#    'version': '2'},
#   'id': '26427870',
#   'pos': [34.0370274, -118.5386695],
#   'type': 'node'},
#  {'created': {'changeset': '5523234',
#    'timestamp': '2010-08-18T04:26:00Z',
#    'uid': '82317',
#    'user': 'AM909',
#    'version': '3'},
#   'id': '26427871',
#   'pos': [34.0365221, -118.5376743],
#   'type': 'node'},
#  {'created': {'changeset': '5523234',
#    'timestamp': '2010-08-18T04:26:00Z',
#    'uid': '82317',
#    'user': 'AM909',
#    'version': '2'},
#   'id': '26427873',
#   'pos': [34.0354565, -118.5359181],
#   'type': 'node'},
#  {'created': {'changeset': '5523234',
#    'timestamp': '2010-08-18T04:25:58Z',
#    'uid': '82317',
#    'user': 'AM909',
#    'version': '2'},
#   'id': '26427874',
#   'pos': [34.0351216, -118.5352643],
#   'type': 'node'},
#  {'created': {'changeset': '19588931',
#    'timestamp': '2013-12-22T20:48:20Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '3'},
#   'id': '26427875',
#   'pos': [34.0321584, -118.5284537],
#   'type': 'node'},
#  {'created': {'changeset': '5523234',
#    'timestamp': '2010-08-18T04:25:57Z',
#    'uid': '82317',
#    'user': 'AM909',
#    'version': '2'},
#   'id': '26427876',
#   'pos': [34.0319025, -118.5273157],
#   'type': 'node'},
#  {'created': {'changeset': '19588931',
#    'timestamp': '2013-12-22T20:48:20Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '2'},
#   'id': '26427877',
#   'pos': [34.0315235, -118.5262226],
#   'type': 'node'},
#  {'created': {'changeset': '33772684',
#    'timestamp': '2015-09-03T13:11:55Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '3'},
#   'id': '26427878',
#   'pos': [34.0312333, -118.5255213],
#   'type': 'node'},
#  {'created': {'changeset': '5523234',
#    'timestamp': '2010-08-18T04:26:03Z',
#    'uid': '82317',
#    'user': 'AM909',
#    'version': '2'},
#   'id': '26427879',
#   'pos': [34.0310769, -118.5261779],
#   'type': 'node'},
#  {'created': {'changeset': '11245718',
#    'timestamp': '2012-04-09T22:09:46Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '21'},
#   'id': '28434268',
#   'pos': [34.0130464, -118.4889079],
#   'type': 'node'},
#  {'created': {'changeset': '11245718',
#    'timestamp': '2012-04-09T22:09:46Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '24'},
#   'id': '28434273',
#   'pos': [34.0133092, -118.4884452],
#   'type': 'node'},
#  {'created': {'changeset': '11398509',
#    'timestamp': '2012-04-23T19:27:46Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '3'},
#   'id': '60954432',
#   'pos': [33.9701779, -118.4455097],
#   'type': 'node'},
#  {'created': {'changeset': '11398509',
#    'timestamp': '2012-04-23T19:27:46Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '3'},
#   'id': '60954433',
#   'pos': [33.9702486, -118.4454983],
#   'type': 'node'},
#  {'created': {'changeset': '11398509',
#    'timestamp': '2012-04-23T19:27:45Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '3'},
#   'id': '60954434',
#   'pos': [33.9707108, -118.4454983],
#   'type': 'node'},
#  {'created': {'changeset': '11398509',
#    'timestamp': '2012-04-23T19:27:46Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '3'},
#   'id': '60954435',
#   'pos': [33.9715313, -118.4455019],
#   'type': 'node'},
#  {'created': {'changeset': '11398509',
#    'timestamp': '2012-04-23T19:27:45Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '3'},
#   'id': '60954436',
#   'pos': [33.9725191, -118.4455038],
#   'type': 'node'},
#  {'created': {'changeset': '11398509',
#    'timestamp': '2012-04-23T19:27:45Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '3'},
#   'id': '60954437',
#   'pos': [33.9734389, -118.4455067],
#   'type': 'node'},
#  {'created': {'changeset': '11398509',
#    'timestamp': '2012-04-23T19:27:45Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '3'},
#   'id': '60954438',
#   'pos': [33.9735872, -118.4454833],
#   'type': 'node'},
#  {'created': {'changeset': '11398509',
#    'timestamp': '2012-04-23T19:27:46Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '3'},
#   'id': '60954439',
#   'pos': [33.97373, -118.4454344],
#   'type': 'node'},
#  {'created': {'changeset': '11398509',
#    'timestamp': '2012-04-23T19:27:45Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '3'},
#   'id': '60954440',
#   'pos': [33.9738337, -118.4453743],
#   'type': 'node'},
#  {'created': {'changeset': '11398509',
#    'timestamp': '2012-04-23T19:27:46Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '3'},
#   'id': '60954441',
#   'pos': [33.9739477, -118.4452772],
#   'type': 'node'},
#  {'created': {'changeset': '11398509',
#    'timestamp': '2012-04-23T19:27:46Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '3'},
#   'id': '60954442',
#   'pos': [33.9741209, -118.4450499],
#   'type': 'node'},
#  {'created': {'changeset': '3375691',
#    'timestamp': '2009-12-14T21:55:07Z',
#    'uid': '131476',
#    'user': 'DMaximus',
#    'version': '2'},
#   'id': '60954443',
#   'pos': [33.9744496, -118.4443199],
#   'type': 'node'},
#  {'created': {'changeset': '3375691',
#    'timestamp': '2009-12-14T21:55:08Z',
#    'uid': '131476',
#    'user': 'DMaximus',
#    'version': '2'},
#   'id': '60954444',
#   'pos': [33.9750369, -118.4430255],
#   'type': 'node'},
#  {'created': {'changeset': '39053959',
#    'timestamp': '2016-05-02T21:56:11Z',
#    'uid': '2655992',
#    'user': 'steverumizen',
#    'version': '5'},
#   'highway': 'traffic_signals',
#   'id': '60957871',
#   'pos': [34.0199551, -118.4449443],
#   'traffic_signals': 'signal',
#   'type': 'node'},
#  {'created': {'changeset': '37249613',
#    'timestamp': '2016-02-16T16:35:18Z',
#    'uid': '1829683',
#    'user': 'Luis36995',
#    'version': '4'},
#   'id': '61719426',
#   'pos': [33.9836014, -118.4448798],
#   'type': 'node'},
#  {'created': {'changeset': '4014168',
#    'timestamp': '2010-03-02T03:26:50Z',
#    'uid': '82317',
#    'user': 'AM909',
#    'version': '12'},
#   'id': '61940547',
#   'pos': [34.0294605, -118.4443153],
#   'type': 'node'},
#  {'created': {'changeset': '4014168',
#    'timestamp': '2010-03-02T03:26:47Z',
#    'uid': '82317',
#    'user': 'AM909',
#    'version': '5'},
#   'id': '122391204',
#   'pos': [34.0159126, -118.4853832],
#   'type': 'node'},
#  {'created': {'changeset': '4014168',
#    'timestamp': '2010-03-02T03:26:47Z',
#    'uid': '82317',
#    'user': 'AM909',
#    'version': '4'},
#   'id': '122391253',
#   'pos': [34.0165549, -118.4827536],
#   'type': 'node'},
#  {'created': {'changeset': '25380134',
#    'timestamp': '2014-09-12T00:42:33Z',
#    'uid': '1679',
#    'user': 'andrewpmk',
#    'version': '5'},
#   'highway': 'traffic_signals',
#   'id': '122391257',
#   'pos': [34.0163156, -118.4830388],
#   'traffic_signals': 'ramp_meter',
#   'type': 'node'},
#  {'created': {'changeset': '3398098',
#    'timestamp': '2009-12-18T03:35:11Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '122391265',
#   'pos': [34.0157754, -118.4837136],
#   'type': 'node'},
#  {'created': {'changeset': '4014168',
#    'timestamp': '2010-03-02T03:26:47Z',
#    'uid': '82317',
#    'user': 'AM909',
#    'version': '5'},
#   'id': '122391267',
#   'pos': [34.0158138, -118.4834043],
#   'type': 'node'},
#  {'created': {'changeset': '35873277',
#    'timestamp': '2015-12-10T20:39:26Z',
#    'uid': '3257518',
#    'user': 'michtallygo',
#    'version': '9'},
#   'highway': 'traffic_signals',
#   'id': '122391686',
#   'pos': [34.0468163, -118.4472752],
#   'type': 'node'},
#  {'created': {'changeset': '34359687',
#    'timestamp': '2015-10-01T03:01:57Z',
#    'uid': '2979730',
#    'user': 'TallyGoJem',
#    'version': '9'},
#   'id': '122391694',
#   'pos': [34.0471532, -118.4460334],
#   'type': 'node'},
#  {'created': {'changeset': '24526483',
#    'timestamp': '2014-08-04T01:41:30Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '6'},
#   'id': '122394372',
#   'pos': [34.0497928, -118.447662],
#   'type': 'node'},
#  {'created': {'changeset': '10593084',
#    'timestamp': '2012-02-05T12:59:41Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '6'},
#   'id': '122394375',
#   'pos': [34.0485356, -118.4465964],
#   'type': 'node'},
#  {'created': {'changeset': '10593084',
#    'timestamp': '2012-02-05T12:59:41Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '6'},
#   'id': '122394378',
#   'pos': [34.0475753, -118.4457826],
#   'type': 'node'},
#  {'created': {'changeset': '10593084',
#    'timestamp': '2012-02-05T12:59:41Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '6'},
#   'id': '122394380',
#   'pos': [34.0473576, -118.4455982],
#   'type': 'node'},
#  {'created': {'changeset': '33218584',
#    'timestamp': '2015-08-09T13:23:45Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '6'},
#   'id': '122395376',
#   'pos': [34.0453521, -118.4438201],
#   'type': 'node'},
#  {'created': {'changeset': '3398098',
#    'timestamp': '2009-12-18T03:35:28Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '4'},
#   'id': '122395910',
#   'pos': [34.0075598, -118.4921777],
#   'type': 'node'},
#  {'created': {'changeset': '37175544',
#    'timestamp': '2016-02-12T19:53:19Z',
#    'uid': '2219338',
#    'user': 'RichRico',
#    'version': '6'},
#   'id': '122395912',
#   'pos': [34.0082744, -118.4912849],
#   'type': 'node'},
#  {'created': {'changeset': '4046659',
#    'timestamp': '2010-03-06T05:18:06Z',
#    'uid': '82317',
#    'user': 'AM909',
#    'version': '4'},
#   'id': '122398547',
#   'pos': [34.0138146, -118.4654513],
#   'type': 'node'},
#  {'created': {'changeset': '11239147',
#    'timestamp': '2012-04-09T15:23:22Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '5'},
#   'id': '122398551',
#   'pos': [34.0134499, -118.4651647],
#   'type': 'node'},
#  {'created': {'changeset': '18576989',
#    'timestamp': '2013-10-28T00:46:54Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '6'},
#   'id': '122411056',
#   'pos': [34.0406934, -118.5300159],
#   'type': 'node'},
#  {'created': {'changeset': '18576989',
#    'timestamp': '2013-10-28T00:46:54Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '4'},
#   'id': '122411059',
#   'pos': [34.0403064, -118.5303006],
#   'type': 'node'},
#  {'created': {'changeset': '18576989',
#    'timestamp': '2013-10-28T00:46:54Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '5'},
#   'id': '122411061',
#   'pos': [34.0399529, -118.5304191],
#   'type': 'node'},
#  {'created': {'changeset': '18576989',
#    'timestamp': '2013-10-28T00:46:54Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '5'},
#   'id': '122411064',
#   'pos': [34.0398429, -118.5304913],
#   'type': 'node'},
#  {'created': {'changeset': '2832611',
#    'timestamp': '2009-10-13T07:10:58Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '4'},
#   'id': '122411067',
#   'pos': [34.0396322, -118.5307952],
#   'type': 'node'},
#  {'created': {'changeset': '3503882',
#    'timestamp': '2009-12-31T20:39:07Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '4'},
#   'id': '122411070',
#   'pos': [34.0395397, -118.5310527],
#   'type': 'node'},
#  {'created': {'changeset': '3503882',
#    'timestamp': '2009-12-31T20:39:07Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '4'},
#   'id': '122411072',
#   'pos': [34.0395966, -118.5312844],
#   'type': 'node'},
#  {'created': {'changeset': '3503882',
#    'timestamp': '2009-12-31T20:39:07Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '5'},
#   'id': '122411075',
#   'pos': [34.0397247, -118.5314904],
#   'type': 'node'},
#  {'created': {'changeset': '3503882',
#    'timestamp': '2009-12-31T20:39:29Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '122418425',
#   'pos': [34.0427118, -118.5288383],
#   'type': 'node'},
#  {'created': {'changeset': '2832611',
#    'timestamp': '2009-10-13T07:16:42Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '5'},
#   'id': '122418427',
#   'pos': [34.0403932, -118.5294047],
#   'type': 'node'},
#  {'created': {'changeset': '8708782',
#    'timestamp': '2011-07-13T04:07:48Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '5'},
#   'id': '122423169',
#   'pos': [34.0361072, -118.5308935],
#   'type': 'node'},
#  {'barrier': 'fence',
#   'created': {'changeset': '8708782',
#    'timestamp': '2011-07-13T04:07:49Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '7'},
#   'id': '122423172',
#   'pos': [34.0359073, -118.5308831],
#   'type': 'node'},
#  {'created': {'changeset': '3562006',
#    'timestamp': '2010-01-07T13:52:55Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '5'},
#   'id': '122438817',
#   'pos': [33.9887652, -118.4707497],
#   'type': 'node'},
#  {'created': {'changeset': '13814723',
#    'timestamp': '2012-11-09T21:42:49Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '5'},
#   'id': '122438819',
#   'pos': [33.9890088, -118.4711504],
#   'type': 'node'},
#  {'created': {'changeset': '24339250',
#    'timestamp': '2014-07-24T22:16:32Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '9'},
#   'id': '122441196',
#   'pos': [34.0236699, -118.4741616],
#   'type': 'node'},
#  {'created': {'changeset': '3503882',
#    'timestamp': '2009-12-31T20:40:31Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '122441199',
#   'pos': [34.0231384, -118.4751477],
#   'type': 'node'},
#  {'created': {'changeset': '11245718',
#    'timestamp': '2012-04-09T22:09:46Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '5'},
#   'id': '122441201',
#   'pos': [34.0225181, -118.4760586],
#   'type': 'node'},
#  {'created': {'changeset': '17786499',
#    'timestamp': '2013-09-11T17:01:00Z',
#    'uid': '1593364',
#    'user': 'Yeliena',
#    'version': '8'},
#   'highway': 'motorway_junction',
#   'id': '122441204',
#   'pos': [34.0209442, -118.4774997],
#   'ref': '1C',
#   'type': 'node'},
#  {'created': {'changeset': '39087295',
#    'timestamp': '2016-05-04T05:36:37Z',
#    'uid': '1707766',
#    'user': 'Christine_E',
#    'version': '4'},
#   'id': '122442341',
#   'pos': [34.0221634, -118.4756225],
#   'type': 'node'},
#  {'created': {'changeset': '3562006',
#    'timestamp': '2010-01-07T13:52:57Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '4'},
#   'id': '122442506',
#   'pos': [33.9856265, -118.4649628],
#   'type': 'node'},
#  {'created': {'changeset': '3562006',
#    'timestamp': '2010-01-07T13:52:57Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '4'},
#   'id': '122442517',
#   'pos': [33.9857119, -118.4647825],
#   'type': 'node'},
#  {'created': {'changeset': '3562006',
#    'timestamp': '2010-01-07T13:52:57Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '5'},
#   'id': '122442639',
#   'pos': [33.9855126, -118.4648426],
#   'type': 'node'},
#  {'created': {'changeset': '3398098',
#    'timestamp': '2009-12-18T03:39:05Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '7'},
#   'id': '122450380',
#   'pos': [33.9850144, -118.4644049],
#   'type': 'node'},
#  {'created': {'changeset': '3398098',
#    'timestamp': '2009-12-18T03:39:05Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '5'},
#   'id': '122450394',
#   'pos': [33.9851283, -118.4642676],
#   'type': 'node'},
#  {'created': {'changeset': '3398098',
#    'timestamp': '2009-12-18T03:39:38Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '5'},
#   'id': '122458070',
#   'pos': [33.984929, -118.4640959],
#   'type': 'node'},
#  {'created': {'changeset': '3398098',
#    'timestamp': '2009-12-18T03:39:41Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '4'},
#   'id': '122458950',
#   'pos': [34.0396656, -118.5278429],
#   'type': 'node'},
#  {'created': {'changeset': '3398098',
#    'timestamp': '2009-12-18T03:39:41Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '4'},
#   'id': '122458953',
#   'pos': [34.0395234, -118.5274653],
#   'type': 'node'},
#  {'created': {'changeset': '3398098',
#    'timestamp': '2009-12-18T03:39:41Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '5'},
#   'id': '122458956',
#   'pos': [34.0390774, -118.5269843],
#   'type': 'node'},
#  {'created': {'changeset': '3398098',
#    'timestamp': '2009-12-18T03:39:41Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '5'},
#   'id': '122458958',
#   'pos': [34.038921, -118.5270959],
#   'type': 'node'},
#  {'created': {'changeset': '2832611',
#    'timestamp': '2009-10-13T07:40:46Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '5'},
#   'id': '122458959',
#   'pos': [34.038736, -118.5271989],
#   'type': 'node'},
#  {'created': {'changeset': '3398098',
#    'timestamp': '2009-12-18T03:39:41Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '5'},
#   'id': '122458960',
#   'pos': [34.0385796, -118.5273019],
#   'type': 'node'},
#  {'created': {'changeset': '3398098',
#    'timestamp': '2009-12-18T03:39:41Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '5'},
#   'id': '122458961',
#   'pos': [34.038379, -118.5274291],
#   'type': 'node'},
#  {'created': {'changeset': '3398098',
#    'timestamp': '2009-12-18T03:39:41Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '5'},
#   'id': '122458963',
#   'pos': [34.0384302, -118.5277139],
#   'type': 'node'},
#  {'created': {'changeset': '11239147',
#    'timestamp': '2012-04-09T15:23:20Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '5'},
#   'highway': 'turning_circle',
#   'id': '122459327',
#   'pos': [34.0287965, -118.4492543],
#   'type': 'node'},
#  {'created': {'changeset': '5524344',
#    'timestamp': '2010-08-18T08:23:11Z',
#    'uid': '82317',
#    'user': 'AM909',
#    'version': '5'},
#   'id': '122465917',
#   'pos': [34.0394624, -118.5360698],
#   'type': 'node'},
#  {'created': {'changeset': '3398098',
#    'timestamp': '2009-12-18T03:40:12Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '4'},
#   'id': '122465918',
#   'pos': [34.0402857, -118.5397691],
#   'type': 'node'},
#  {'created': {'changeset': '3562006',
#    'timestamp': '2010-01-07T13:53:19Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '4'},
#   'id': '122474300',
#   'pos': [33.9816353, -118.4557193],
#   'type': 'node'},
#  {'created': {'changeset': '12532634',
#    'timestamp': '2012-07-29T10:07:21Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '5'},
#   'id': '122474302',
#   'pos': [33.9815432, -118.455703],
#   'type': 'node'},
#  {'created': {'changeset': '3562006',
#    'timestamp': '2010-01-07T13:53:19Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '4'},
#   'id': '122474303',
#   'pos': [33.9813506, -118.4555651],
#   'type': 'node'},
#  {'created': {'changeset': '3499964',
#    'timestamp': '2009-12-31T12:06:15Z',
#    'uid': '167417',
#    'user': 'osm-sputnik',
#    'version': '4'},
#   'id': '122474306',
#   'pos': [33.9812405, -118.4553572],
#   'type': 'node'},
#  {'created': {'changeset': '3562006',
#    'timestamp': '2010-01-07T13:53:19Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '4'},
#   'id': '122474309',
#   'pos': [33.9812205, -118.4552016],
#   'type': 'node'},
#  {'created': {'changeset': '3562006',
#    'timestamp': '2010-01-07T13:53:19Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '4'},
#   'id': '122474310',
#   'pos': [33.981225, -118.4514278],
#   'type': 'node'},
#  {'created': {'changeset': '3562006',
#    'timestamp': '2010-01-07T13:53:19Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '4'},
#   'id': '122474312',
#   'pos': [33.9813162, -118.4511837],
#   'type': 'node'},
#  {'created': {'changeset': '3562006',
#    'timestamp': '2010-01-07T13:53:19Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '4'},
#   'id': '122474315',
#   'pos': [33.9814073, -118.4511139],
#   'type': 'node'},
#  {'created': {'changeset': '3499964',
#    'timestamp': '2009-12-31T12:06:16Z',
#    'uid': '167417',
#    'user': 'osm-sputnik',
#    'version': '3'},
#   'id': '122474318',
#   'pos': [33.9815097, -118.4510952],
#   'type': 'node'},
#  {'created': {'changeset': '3562006',
#    'timestamp': '2010-01-07T13:53:20Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '4'},
#   'id': '122474320',
#   'pos': [33.9819523, -118.4511461],
#   'type': 'node'},
#  {'created': {'changeset': '2449110',
#    'timestamp': '2009-09-11T18:28:07Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '6'},
#   'id': '122476475',
#   'pos': [33.9973224, -118.4799021],
#   'type': 'node'},
#  {'created': {'changeset': '3562006',
#    'timestamp': '2010-01-07T13:53:22Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '5'},
#   'id': '122476479',
#   'pos': [33.997671, -118.4792326],
#   'type': 'node'},
#  {'created': {'changeset': '3562006',
#    'timestamp': '2010-01-07T13:53:22Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '4'},
#   'id': '122476483',
#   'pos': [33.998077, -118.4784809],
#   'type': 'node'},
#  {'created': {'changeset': '3562006',
#    'timestamp': '2010-01-07T13:53:22Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '4'},
#   'id': '122476486',
#   'pos': [33.9985111, -118.4775797],
#   'type': 'node'},
#  {'created': {'changeset': '3562006',
#    'timestamp': '2010-01-07T13:53:22Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '4'},
#   'id': '122476490',
#   'pos': [33.9990804, -118.4765841],
#   'type': 'node'},
#  {'created': {'changeset': '3061053',
#    'timestamp': '2009-11-08T07:42:58Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '6'},
#   'id': '122476492',
#   'pos': [33.9994931, -118.4758459],
#   'type': 'node'},
#  {'created': {'changeset': '11364530',
#    'timestamp': '2012-04-20T14:47:32Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '6'},
#   'id': '122479829',
#   'pos': [33.9843074, -118.4631091],
#   'type': 'node'},
#  {'created': {'changeset': '12528813',
#    'timestamp': '2012-07-28T21:54:54Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '6'},
#   'id': '122479832',
#   'pos': [33.9839447, -118.4629134],
#   'type': 'node'},
#  {'created': {'changeset': '29084501',
#    'timestamp': '2015-02-25T05:19:26Z',
#    'uid': '402624',
#    'user': 'bdiscoe',
#    'version': '9'},
#   'id': '122485512',
#   'pos': [34.0395992, -118.5058172],
#   'type': 'node'},
#  {'created': {'changeset': '3398098',
#    'timestamp': '2009-12-18T03:40:52Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '6'},
#   'id': '122485541',
#   'pos': [34.0509669, -118.4976651],
#   'type': 'node'},
#  {'created': {'changeset': '3398098',
#    'timestamp': '2009-12-18T03:40:52Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '5'},
#   'id': '122485547',
#   'pos': [34.0486154, -118.4944176],
#   'type': 'node'},
#  {'created': {'changeset': '8154478',
#    'timestamp': '2011-05-15T17:22:10Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '5'},
#   'id': '122497595',
#   'pos': [34.0048322, -118.4884484],
#   'type': 'node'},
#  {'created': {'changeset': '22413375',
#    'timestamp': '2014-05-18T19:45:05Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '5'},
#   'id': '122497597',
#   'pos': [34.0044538, -118.488075],
#   'type': 'node'},
#  {'created': {'changeset': '22413375',
#    'timestamp': '2014-05-18T19:45:05Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '5'},
#   'id': '122497599',
#   'pos': [34.0040865, -118.4877124],
#   'type': 'node'},
#  {'created': {'changeset': '24339250',
#    'timestamp': '2014-07-24T22:42:03Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '10'},
#   'id': '122499374',
#   'pos': [33.9916297, -118.4739705],
#   'type': 'node'},
#  {'created': {'changeset': '24339250',
#    'timestamp': '2014-07-24T22:42:03Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '9'},
#   'id': '122499377',
#   'pos': [33.9914096, -118.4737921],
#   'type': 'node'},
#  {'created': {'changeset': '24339250',
#    'timestamp': '2014-07-24T22:42:03Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '9'},
#   'id': '122499381',
#   'pos': [33.9911767, -118.4736032],
#   'type': 'node'},
#  {'created': {'changeset': '11356130',
#    'timestamp': '2012-04-19T17:21:14Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '7'},
#   'id': '122499383',
#   'pos': [33.990732, -118.4732425],
#   'type': 'node'},
#  {'created': {'changeset': '18258347',
#    'timestamp': '2013-10-09T05:08:05Z',
#    'uid': '14293',
#    'user': 'KindredCoda',
#    'version': '6'},
#   'id': '122500746',
#   'pos': [34.0474043, -118.4484981],
#   'type': 'node'},
#  {'created': {'changeset': '18258347',
#    'timestamp': '2013-10-09T04:54:26Z',
#    'uid': '14293',
#    'user': 'KindredCoda',
#    'version': '7'},
#   'id': '122500748',
#   'pos': [34.0466465, -118.4478454],
#   'type': 'node'},
#  {'created': {'changeset': '18258347',
#    'timestamp': '2013-10-09T05:08:05Z',
#    'uid': '14293',
#    'user': 'KindredCoda',
#    'version': '6'},
#   'id': '122500750',
#   'pos': [34.0456345, -118.4469737],
#   'type': 'node'},
#  {'created': {'changeset': '11268439',
#    'timestamp': '2012-04-11T18:31:21Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '6'},
#   'id': '122502273',
#   'pos': [34.028841, -118.4547258],
#   'type': 'node'},
#  {'created': {'changeset': '3398098',
#    'timestamp': '2009-12-18T03:43:05Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '6'},
#   'id': '122503045',
#   'pos': [34.0472595, -118.5277355],
#   'type': 'node'},
#  {'created': {'changeset': '3398098',
#    'timestamp': '2009-12-18T03:43:05Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '5'},
#   'id': '122503048',
#   'pos': [34.0448892, -118.5283376],
#   'type': 'node'},
#  {'created': {'changeset': '6053598',
#    'timestamp': '2010-10-16T01:22:02Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '5'},
#   'id': '122503051',
#   'pos': [34.0449148, -118.5285468],
#   'type': 'node'},
#  {'created': {'changeset': '3398098',
#    'timestamp': '2009-12-18T03:43:09Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '122503906',
#   'pos': [34.0067895, -118.4714303],
#   'type': 'node'},
#  {'created': {'changeset': '21467474',
#    'timestamp': '2014-04-02T22:47:59Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '6'},
#   'id': '122503908',
#   'pos': [34.0071527, -118.4717992],
#   'type': 'node'},
#  {'created': {'changeset': '8153808',
#    'timestamp': '2011-05-15T16:24:03Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '6'},
#   'id': '122503910',
#   'pos': [34.0075225, -118.4721762],
#   'type': 'node'},
#  {'created': {'changeset': '8153808',
#    'timestamp': '2011-05-15T16:24:03Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '5'},
#   'id': '122503912',
#   'pos': [34.0078895, -118.4725496],
#   'type': 'node'},
#  {'created': {'changeset': '8153808',
#    'timestamp': '2011-05-15T16:24:03Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '4'},
#   'id': '122503914',
#   'pos': [34.0082664, -118.4729331],
#   'type': 'node'},
#  {'created': {'changeset': '4014168',
#    'timestamp': '2010-03-02T03:26:47Z',
#    'uid': '82317',
#    'user': 'AM909',
#    'version': '5'},
#   'id': '122510313',
#   'pos': [34.0145978, -118.4853899],
#   'type': 'node'},
#  {'created': {'changeset': '11239147',
#    'timestamp': '2012-04-09T15:23:28Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '4'},
#   'id': '122515268',
#   'pos': [34.0147316, -118.4662258],
#   'type': 'node'},
#  {'created': {'changeset': '3398098',
#    'timestamp': '2009-12-18T03:44:28Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '6'},
#   'id': '122518649',
#   'pos': [34.0377901, -118.5271474],
#   'type': 'node'},
#  {'created': {'changeset': '3398098',
#    'timestamp': '2009-12-18T03:44:28Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '6'},
#   'id': '122518666',
#   'pos': [34.0369935, -118.5265723],
#   'type': 'node'},
#  {'created': {'changeset': '2832611',
#    'timestamp': '2009-10-13T07:37:13Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '4'},
#   'id': '122518669',
#   'pos': [34.0370433, -118.5262547],
#   'type': 'node'},
#  {'created': {'changeset': '19588931',
#    'timestamp': '2013-12-22T20:48:19Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '7'},
#   'id': '122519558',
#   'pos': [34.0406475, -118.5233291],
#   'type': 'node'},
#  {'created': {'changeset': '3503882',
#    'timestamp': '2009-12-31T20:41:39Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '4'},
#   'id': '122519566',
#   'pos': [34.0407844, -118.5238535],
#   'type': 'node'},
#  {'created': {'changeset': '3503882',
#    'timestamp': '2009-12-31T20:41:40Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '4'},
#   'id': '122519569',
#   'pos': [34.0408342, -118.5239822],
#   'type': 'node'},
#  {'created': {'changeset': '3503882',
#    'timestamp': '2009-12-31T20:41:40Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '4'},
#   'id': '122519571',
#   'pos': [34.0409196, -118.5240251],
#   'type': 'node'},
#  {'created': {'changeset': '3503882',
#    'timestamp': '2009-12-31T20:41:40Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '4'},
#   'id': '122519573',
#   'pos': [34.0409693, -118.524171],
#   'type': 'node'},
#  {'created': {'changeset': '2831623',
#    'timestamp': '2009-10-13T00:01:56Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '4'},
#   'id': '122519576',
#   'pos': [34.0409907, -118.524274],
#   'type': 'node'},
#  {'created': {'changeset': '22552727',
#    'timestamp': '2014-05-25T22:40:36Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '4'},
#   'id': '122532326',
#   'pos': [34.0356474, -118.5073263],
#   'type': 'node'},
#  {'created': {'changeset': '22552727',
#    'timestamp': '2014-05-25T22:40:36Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '4'},
#   'id': '122532330',
#   'pos': [34.0359754, -118.5072984],
#   'type': 'node'},
#  {'created': {'changeset': '11359425',
#    'timestamp': '2012-04-19T23:39:50Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '4'},
#   'id': '122534218',
#   'pos': [33.9674092, -118.453296],
#   'type': 'node'},
#  {'created': {'changeset': '3061633',
#    'timestamp': '2009-11-08T09:56:58Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '4'},
#   'id': '122534937',
#   'pos': [33.9941418, -118.4731928],
#   'type': 'node'},
#  {'created': {'changeset': '3603428',
#    'timestamp': '2010-01-12T14:19:06Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '4'},
#   'id': '122534940',
#   'pos': [33.9930886, -118.4731413],
#   'type': 'node'},
#  {'created': {'changeset': '5515413',
#    'timestamp': '2010-08-17T08:15:35Z',
#    'uid': '82317',
#    'user': 'AM909',
#    'version': '7'},
#   'id': '122540316',
#   'pos': [34.0120073, -118.4900068],
#   'type': 'node'},
#  {'created': {'changeset': '37268295',
#    'timestamp': '2016-02-17T14:28:58Z',
#    'uid': '1829683',
#    'user': 'Luis36995',
#    'version': '8'},
#   'id': '122543311',
#   'pos': [34.0248219, -118.4696269],
#   'type': 'node'},
#  {'created': {'changeset': '3562050',
#    'timestamp': '2010-01-07T13:55:42Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '4'},
#   'id': '122543316',
#   'pos': [34.0248386, -118.467792],
#   'type': 'node'},
#  {'created': {'changeset': '3070225',
#    'timestamp': '2009-11-09T04:13:03Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '5'},
#   'id': '122545026',
#   'pos': [33.9926863, -118.4588965],
#   'type': 'node'},
#  {'created': {'changeset': '3603428',
#    'timestamp': '2010-01-12T14:19:13Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '4'},
#   'id': '122545029',
#   'pos': [33.9942912, -118.457769],
#   'type': 'node'},
#  {'created': {'changeset': '37250929',
#    'timestamp': '2016-02-16T17:41:57Z',
#    'uid': '1829683',
#    'user': 'Luis36995',
#    'version': '10'},
#   'id': '122545030',
#   'pos': [33.9959295, -118.4566357],
#   'type': 'node'},
#  {'created': {'changeset': '3603428',
# ...
#    'timestamp': '2011-11-03T21:37:55Z',
#    'uid': '339764',
#    'user': 'Adler',
#    'version': '10'},
#   'id': '122738747',
#   'pos': [34.0319729, -118.4727503],
#   'type': 'node'},
#  {'created': {'changeset': '21430033',
#    'timestamp': '2014-03-31T23:06:18Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '7'},
#   'id': '122738750',
#   'pos': [34.0333654, -118.4709811],
#   'type': 'node'},
#  {'created': {'changeset': '18567431',
#    'timestamp': '2013-10-27T14:54:54Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '10'},
#   'id': '122738752',
#   'pos': [34.0349868, -118.4689573],
#   'type': 'node'},
#  {'created': {'changeset': '18567431',
#    'timestamp': '2013-10-27T14:54:54Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '7'},
#   'id': '122738754',
#   'pos': [34.0357565, -118.4680033],
#   'type': 'node'},
#  {'created': {'changeset': '3603434',
#    'timestamp': '2010-01-12T14:23:41Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '5'},
#   'id': '122738758',
#   'pos': [34.0372976, -118.4661607],
#   'type': 'node'},
#  {'created': {'changeset': '5524344',
#    'timestamp': '2010-08-18T08:22:34Z',
#    'uid': '82317',
#    'user': 'AM909',
#    'version': '5'},
#   'id': '122741420',
#   'noexit': 'yes',
#   'pos': [34.0368838, -118.5358053],
#   'type': 'node'},
#  {'created': {'changeset': '6405600',
#    'timestamp': '2010-11-19T10:40:50Z',
#    'uid': '356178',
#    'user': 'dan3831',
#    'version': '7'},
#   'id': '122741641',
#   'pos': [33.9912667, -118.4774626],
#   'type': 'node'},
#  {'created': {'changeset': '18839148',
#    'timestamp': '2013-11-11T16:43:24Z',
#    'uid': '1593364',
#    'user': 'Yeliena',
#    'version': '5'},
#   'id': '122741776',
#   'pos': [34.0143856, -118.4572766],
#   'type': 'node'},
#  {'created': {'changeset': '8153808',
#    'timestamp': '2011-05-15T16:24:04Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '4'},
#   'id': '122741779',
#   'pos': [34.0135666, -118.4565987],
#   'type': 'node'},
#  {'created': {'changeset': '18576989',
#    'timestamp': '2013-10-28T00:46:54Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '8'},
#   'id': '122742207',
#   'pos': [34.0303242, -118.5205223],
#   'type': 'node'},
#  {'created': {'changeset': '3610130',
#    'timestamp': '2010-01-13T14:05:14Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '6'},
#   'id': '122742208',
#   'pos': [34.0329748, -118.5200769],
#   'type': 'node'},
#  {'created': {'changeset': '20038570',
#    'timestamp': '2014-01-16T18:33:38Z',
#    'uid': '1679',
#    'user': 'andrewpmk',
#    'version': '8'},
#   'highway': 'stop',
#   'id': '122742209',
#   'pos': [34.0339093, -118.5204535],
#   'type': 'node'},
#  {'created': {'changeset': '3610130',
#    'timestamp': '2010-01-13T14:05:14Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '5'},
#   'id': '122742212',
#   'pos': [34.0348083, -118.5206202],
#   'type': 'node'},
#  {'created': {'changeset': '3610130',
#    'timestamp': '2010-01-13T14:05:14Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '7'},
#   'id': '122742214',
#   'pos': [34.0364245, -118.5200855],
#   'type': 'node'},
#  {'created': {'changeset': '6053598',
#    'timestamp': '2010-10-16T01:38:48Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '6'},
#   'id': '122742215',
#   'pos': [34.0407686, -118.5195856],
#   'type': 'node'},
#  {'created': {'changeset': '3610130',
#    'timestamp': '2010-01-13T14:05:14Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '5'},
#   'id': '122742217',
#   'pos': [34.041076, -118.5197679],
#   'type': 'node'},
#  {'created': {'changeset': '19588931',
#    'timestamp': '2013-12-22T20:48:20Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '5'},
#   'id': '122742219',
#   'pos': [34.0424166, -118.5212214],
#   'type': 'node'},
#  {'created': {'changeset': '20038570',
#    'timestamp': '2014-01-16T18:33:38Z',
#    'uid': '1679',
#    'user': 'andrewpmk',
#    'version': '6'},
#   'highway': 'stop',
#   'id': '122742222',
#   'pos': [34.0442704, -118.5234538],
#   'type': 'node'},
#  {'created': {'changeset': '20038570',
#    'timestamp': '2014-01-16T18:33:38Z',
#    'uid': '1679',
#    'user': 'andrewpmk',
#    'version': '7'},
#   'highway': 'stop',
#   'id': '122742223',
#   'pos': [34.0440611, -118.5245375],
#   'type': 'node'},
#  {'created': {'changeset': '3610130',
#    'timestamp': '2010-01-13T14:05:22Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '4'},
#   'id': '122743724',
#   'pos': [34.0376347, -118.5383545],
#   'type': 'node'},
#  {'created': {'changeset': '5524344',
#    'timestamp': '2010-08-18T08:22:44Z',
#    'uid': '82317',
#    'user': 'AM909',
#    'version': '4'},
#   'id': '122743728',
#   'noexit': 'yes',
#   'pos': [34.0374307, -118.5377528],
#   'type': 'node'},
#  {'created': {'changeset': '3610130',
#    'timestamp': '2010-01-13T14:05:31Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '7'},
#   'id': '122745405',
#   'pos': [34.0326405, -118.5245745],
#   'type': 'node'},
#  {'created': {'changeset': '6053598',
#    'timestamp': '2010-10-16T02:00:54Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '8'},
#   'id': '122745407',
#   'pos': [34.0336216, -118.5241453],
#   'type': 'node'},
#  {'created': {'changeset': '3610130',
#    'timestamp': '2010-01-13T14:05:31Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '7'},
#   'id': '122745408',
#   'pos': [34.0347743, -118.5236904],
#   'type': 'node'},
#  {'created': {'changeset': '20038570',
#    'timestamp': '2014-01-16T18:33:38Z',
#    'uid': '1679',
#    'user': 'andrewpmk',
#    'version': '8'},
#   'highway': 'stop',
#   'id': '122745409',
#   'pos': [34.0363107, -118.5225145],
#   'type': 'node'},
#  {'created': {'changeset': '3610130',
#    'timestamp': '2010-01-13T14:05:31Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '6'},
#   'id': '122745412',
#   'pos': [34.0379608, -118.5228578],
#   'type': 'node'},
#  {'created': {'changeset': '3610130',
#    'timestamp': '2010-01-13T14:05:31Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '5'},
#   'id': '122745415',
#   'pos': [34.0390134, -118.5238792],
#   'type': 'node'},
#  {'created': {'changeset': '24412024',
#    'timestamp': '2014-07-28T22:09:08Z',
#    'uid': '1679',
#    'user': 'andrewpmk',
#    'version': '6'},
#   'highway': 'stop',
#   'id': '122745417',
#   'pos': [34.0426679, -118.5229151],
#   'type': 'node'},
#  {'created': {'changeset': '6053598',
#    'timestamp': '2010-10-16T01:21:57Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '6'},
#   'id': '122745419',
#   'pos': [34.0455882, -118.5251243],
#   'type': 'node'},
#  {'created': {'changeset': '10736533',
#    'timestamp': '2012-02-20T00:44:54Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '4'},
#   'id': '122748078',
#   'pos': [34.0032371, -118.4721323],
#   'type': 'node'},
#  {'created': {'changeset': '3503882',
#    'timestamp': '2009-12-31T20:52:51Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '122748080',
#   'pos': [34.0026988, -118.4716821],
#   'type': 'node'},
#  {'created': {'changeset': '3503882',
#    'timestamp': '2009-12-31T20:52:51Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '122748081',
#   'pos': [34.002215, -118.4712958],
#   'type': 'node'},
#  {'created': {'changeset': '31781707',
#    'timestamp': '2015-06-07T05:20:56Z',
#    'uid': '1427293',
#    'user': 'kingrollo',
#    'version': '6'},
#   'id': '122748157',
#   'pos': [33.9848709, -118.4551845],
#   'type': 'node'},
#  {'created': {'changeset': '31781707',
#    'timestamp': '2015-06-07T05:20:56Z',
#    'uid': '1427293',
#    'user': 'kingrollo',
#    'version': '3'},
#   'id': '122748159',
#   'pos': [33.9845096, -118.4532672],
#   'type': 'node'},
#  {'created': {'changeset': '31781707',
#    'timestamp': '2015-06-07T05:20:56Z',
#    'uid': '1427293',
#    'user': 'kingrollo',
#    'version': '7'},
#   'id': '122748160',
#   'pos': [33.984539, -118.4527191],
#   'type': 'node'},
#  {'created': {'changeset': '31781707',
#    'timestamp': '2015-06-07T05:20:56Z',
#    'uid': '1427293',
#    'user': 'kingrollo',
#    'version': '7'},
#   'id': '122748161',
#   'pos': [33.9853362, -118.4525957],
#   'type': 'node'},
#  {'created': {'changeset': '24339250',
#    'timestamp': '2014-07-24T22:42:02Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '8'},
#   'id': '122748995',
#   'pos': [34.004722, -118.466866],
#   'type': 'node'},
#  {'created': {'changeset': '3503882',
#    'timestamp': '2009-12-31T20:53:00Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'highway': 'turning_circle',
#   'id': '122748998',
#   'pos': [34.004168, -118.4678894],
#   'type': 'node'},
#  {'created': {'changeset': '3503882',
#    'timestamp': '2009-12-31T20:53:00Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '122749001',
#   'pos': [34.0040684, -118.4680439],
#   'type': 'node'},
#  {'created': {'changeset': '3503882',
#    'timestamp': '2009-12-31T20:53:00Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '4'},
#   'id': '122749003',
#   'pos': [34.0034066, -118.4692456],
#   'type': 'node'},
#  {'created': {'changeset': '3503882',
#    'timestamp': '2009-12-31T20:53:00Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '5'},
#   'id': '122749005',
#   'pos': [34.0026809, -118.4705244],
#   'type': 'node'},
#  {'created': {'changeset': '3503882',
#    'timestamp': '2009-12-31T20:53:00Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '4'},
#   'id': '122749006',
#   'pos': [34.0012791, -118.4729105],
#   'type': 'node'},
#  {'created': {'changeset': '3503882',
#    'timestamp': '2009-12-31T20:53:00Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '6'},
#   'id': '122749007',
#   'pos': [34.0006633, -118.4740285],
#   'type': 'node'},
#  {'created': {'changeset': '11362991',
#    'timestamp': '2012-04-20T12:32:40Z',
#    'uid': '602634',
#    'user': 'matx17',
#    'version': '8'},
#   'id': '122749022',
#   'pos': [33.9952397, -118.4809976],
#   'type': 'node'},
#  {'created': {'changeset': '13814723',
#    'timestamp': '2012-11-09T21:42:49Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '8'},
#   'id': '122749025',
#   'pos': [33.9964297, -118.4791942],
#   'type': 'node'},
#  {'created': {'changeset': '11367118',
#    'timestamp': '2012-04-20T18:37:17Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '6'},
#   'id': '122750640',
#   'pos': [33.9894489, -118.4498165],
#   'type': 'node'},
#  {'created': {'changeset': '12528813',
#    'timestamp': '2012-07-28T22:00:03Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '5'},
#   'id': '122751360',
#   'pos': [33.9728699, -118.4590295],
#   'type': 'node'},
#  {'created': {'changeset': '12709711',
#    'timestamp': '2012-08-13T07:43:03Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '6'},
#   'id': '122751363',
#   'pos': [33.9733313, -118.458137],
#   'type': 'node'},
#  {'created': {'changeset': '3562050',
#    'timestamp': '2010-01-07T14:15:57Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '6'},
#   'id': '122764161',
#   'pos': [34.0210339, -118.4959605],
#   'type': 'node'},
#  {'created': {'changeset': '21429327',
#    'timestamp': '2014-03-31T21:55:50Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '8'},
#   'id': '122764166',
#   'pos': [34.0224175, -118.4975713],
#   'type': 'node'},
#  {'created': {'changeset': '21429327',
#    'timestamp': '2014-03-31T21:55:50Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '10'},
#   'id': '122764167',
#   'pos': [34.0237699, -118.4991458],
#   'type': 'node'},
#  {'created': {'changeset': '11359425',
#    'timestamp': '2012-04-20T01:05:19Z',
#    'uid': '104962',
#    'user': 'techlady',
#    'version': '9'},
#   'id': '122764826',
#   'pos': [33.9781057, -118.4437595],
#   'type': 'node'},
#  {'created': {'changeset': '3562006',
#    'timestamp': '2010-01-07T14:08:59Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '5'},
#   'id': '122765254',
#   'pos': [33.9889431, -118.4690074],
#   'type': 'node'},
#  {'created': {'changeset': '35544411',
#    'timestamp': '2015-11-24T06:53:13Z',
#    'uid': '589596',
#    'user': 'lxbarth',
#    'version': '6'},
#   'id': '122765255',
#   'pos': [33.9890408, -118.4673401],
#   'type': 'node'},
#  {'created': {'changeset': '4518035',
#    'timestamp': '2010-04-25T07:16:18Z',
#    'uid': '202256',
#    'user': 'Telecas',
#    'version': '6'},
#   'id': '122765259',
#   'pos': [33.9891321, -118.4657557],
#   'type': 'node'},
#  {'created': {'changeset': '3562006',
#    'timestamp': '2010-01-07T14:08:59Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '5'},
#   'id': '122765261',
#   'pos': [33.9892104, -118.4647343],
#   'type': 'node'},
#  {'created': {'changeset': '3562006',
#    'timestamp': '2010-01-07T14:08:59Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '5'},
#   'id': '122765264',
#   'pos': [33.9893385, -118.464288],
#   'type': 'node'},
#  {'created': {'changeset': '3562006',
#    'timestamp': '2010-01-07T14:08:59Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '5'},
#   'id': '122765266',
#   'pos': [33.9899141, -118.4637707],
#   'type': 'node'},
#  {'created': {'changeset': '3610130',
#    'timestamp': '2010-01-13T14:05:38Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '6'},
#   'id': '122767022',
#   'pos': [34.020868, -118.5059495],
#   'type': 'node'},
#  {'created': {'changeset': '21429327',
#    'timestamp': '2014-03-31T21:55:50Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '9'},
#   'id': '122767024',
#   'pos': [34.0216508, -118.5049841],
#   'type': 'node'},
#  {'created': {'changeset': '8150753',
#    'timestamp': '2011-05-15T12:42:43Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '8'},
#   'id': '122767026',
#   'pos': [34.022049, -118.5044928],
#   'type': 'node'},
#  {'created': {'changeset': '24339250',
#    'timestamp': '2014-07-24T22:13:11Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '9'},
#   'id': '122767028',
#   'pos': [34.022425, -118.5040291],
#   'type': 'node'},
#  {'created': {'changeset': '24339250',
#    'timestamp': '2014-07-24T22:13:11Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '10'},
#   'id': '122767030',
#   'pos': [34.0231928, -118.5030822],
#   'type': 'node'},
#  {'created': {'changeset': '8150753',
#    'timestamp': '2011-05-15T12:42:44Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '8'},
#   'id': '122767032',
#   'pos': [34.023574, -118.5026119],
#   'type': 'node'},
#  {'created': {'changeset': '24339250',
#    'timestamp': '2014-07-24T22:13:11Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '10'},
#   'id': '122767033',
#   'pos': [34.0239576, -118.50215],
#   'type': 'node'},
#  {'created': {'changeset': '24339250',
#    'timestamp': '2014-07-24T22:13:11Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '10'},
#   'id': '122767034',
#   'pos': [34.024725, -118.5011923],
#   'type': 'node'},
#  {'created': {'changeset': '24339250',
#    'timestamp': '2014-07-24T22:13:11Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '9'},
#   'id': '122767035',
#   'pos': [34.0255012, -118.5002348],
#   'type': 'node'},
#  {'created': {'changeset': '24339250',
#    'timestamp': '2014-07-24T22:13:11Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '11'},
#   'id': '122767036',
#   'pos': [34.0262667, -118.4992907],
#   'type': 'node'},
#  {'created': {'changeset': '21429517',
#    'timestamp': '2014-03-31T22:16:37Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '10'},
#   'id': '122767038',
#   'pos': [34.0266467, -118.498822],
#   'type': 'node'},
#  {'created': {'changeset': '19588931',
#    'timestamp': '2013-12-22T20:48:20Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '11'},
#   'id': '122767040',
#   'pos': [34.0270214, -118.4983598],
#   'type': 'node'},
#  {'created': {'changeset': '8150753',
#    'timestamp': '2011-05-15T12:42:44Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '9'},
#   'id': '122767042',
#   'pos': [34.0274158, -118.4978732],
#   'type': 'node'},
#  {'created': {'changeset': '8150753',
#    'timestamp': '2011-05-15T12:42:44Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '10'},
#   'id': '122767044',
#   'pos': [34.0277951, -118.4974055],
#   'type': 'node'},
#  ...]

# %%
data = process_map(SM_data)

# %% [markdown]
# ## Opening the Dataset in MongoDB

# %%
from pymongo import MongoClient

# %%
client  = MongoClient('mongodb://localhost:27017')
db = client.examples

# %%
[db.St_Monica_CA.insert(e) for e in data]
# Out:
# C:\Users\Rahel G G\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#   if __name__ == '__main__':
# [ObjectId('57929ed83c97f7303c323998'),
#  ObjectId('57929ed83c97f7303c323999'),
#  ObjectId('57929ed83c97f7303c32399a'),
#  ObjectId('57929ed83c97f7303c32399b'),
#  ObjectId('57929ed83c97f7303c32399c'),
#  ObjectId('57929ed83c97f7303c32399d'),
#  ObjectId('57929ed83c97f7303c32399e'),
#  ObjectId('57929ed83c97f7303c32399f'),
#  ObjectId('57929ed83c97f7303c3239a0'),
#  ObjectId('57929ed83c97f7303c3239a1'),
#  ObjectId('57929ed83c97f7303c3239a2'),
#  ObjectId('57929ed83c97f7303c3239a3'),
#  ObjectId('57929ed83c97f7303c3239a4'),
#  ObjectId('57929ed83c97f7303c3239a5'),
#  ObjectId('57929ed83c97f7303c3239a6'),
#  ObjectId('57929ed83c97f7303c3239a7'),
#  ObjectId('57929ed83c97f7303c3239a8'),
#  ObjectId('57929ed83c97f7303c3239a9'),
#  ObjectId('57929ed83c97f7303c3239aa'),
#  ObjectId('57929ed83c97f7303c3239ab'),
#  ObjectId('57929ed83c97f7303c3239ac'),
#  ObjectId('57929ed83c97f7303c3239ad'),
#  ObjectId('57929ed83c97f7303c3239ae'),
#  ObjectId('57929ed83c97f7303c3239af'),
#  ObjectId('57929ed83c97f7303c3239b0'),
#  ObjectId('57929ed83c97f7303c3239b1'),
#  ObjectId('57929ed83c97f7303c3239b2'),
#  ObjectId('57929ed83c97f7303c3239b3'),
#  ObjectId('57929ed83c97f7303c3239b4'),
#  ObjectId('57929ed83c97f7303c3239b5'),
#  ObjectId('57929ed83c97f7303c3239b6'),
#  ObjectId('57929ed83c97f7303c3239b7'),
#  ObjectId('57929ed83c97f7303c3239b8'),
#  ObjectId('57929ed83c97f7303c3239b9'),
#  ObjectId('57929ed83c97f7303c3239ba'),
#  ObjectId('57929ed83c97f7303c3239bb'),
#  ObjectId('57929ed83c97f7303c3239bc'),
#  ObjectId('57929ed83c97f7303c3239bd'),
#  ObjectId('57929ed83c97f7303c3239be'),
#  ObjectId('57929ed83c97f7303c3239bf'),
#  ObjectId('57929ed83c97f7303c3239c0'),
#  ObjectId('57929ed83c97f7303c3239c1'),
#  ObjectId('57929ed83c97f7303c3239c2'),
#  ObjectId('57929ed83c97f7303c3239c3'),
#  ObjectId('57929ed83c97f7303c3239c4'),
#  ObjectId('57929ed83c97f7303c3239c5'),
#  ObjectId('57929ed83c97f7303c3239c6'),
#  ObjectId('57929ed83c97f7303c3239c7'),
#  ObjectId('57929ed83c97f7303c3239c8'),
#  ObjectId('57929ed83c97f7303c3239c9'),
#  ObjectId('57929ed83c97f7303c3239ca'),
#  ObjectId('57929ed83c97f7303c3239cb'),
#  ObjectId('57929ed83c97f7303c3239cc'),
#  ObjectId('57929ed83c97f7303c3239cd'),
#  ObjectId('57929ed83c97f7303c3239ce'),
#  ObjectId('57929ed83c97f7303c3239cf'),
#  ObjectId('57929ed83c97f7303c3239d0'),
#  ObjectId('57929ed83c97f7303c3239d1'),
#  ObjectId('57929ed83c97f7303c3239d2'),
#  ObjectId('57929ed83c97f7303c3239d3'),
#  ObjectId('57929ed83c97f7303c3239d4'),
#  ObjectId('57929ed83c97f7303c3239d5'),
#  ObjectId('57929ed83c97f7303c3239d6'),
#  ObjectId('57929ed83c97f7303c3239d7'),
#  ObjectId('57929ed83c97f7303c3239d8'),
#  ObjectId('57929ed83c97f7303c3239d9'),
#  ObjectId('57929ed83c97f7303c3239da'),
#  ObjectId('57929ed83c97f7303c3239db'),
#  ObjectId('57929ed83c97f7303c3239dc'),
#  ObjectId('57929ed83c97f7303c3239dd'),
#  ObjectId('57929ed83c97f7303c3239de'),
#  ObjectId('57929ed83c97f7303c3239df'),
#  ObjectId('57929ed83c97f7303c3239e0'),
#  ObjectId('57929ed83c97f7303c3239e1'),
#  ObjectId('57929ed83c97f7303c3239e2'),
#  ObjectId('57929ed83c97f7303c3239e3'),
#  ObjectId('57929ed83c97f7303c3239e4'),
#  ObjectId('57929ed83c97f7303c3239e5'),
#  ObjectId('57929ed83c97f7303c3239e6'),
#  ObjectId('57929ed83c97f7303c3239e7'),
#  ObjectId('57929ed83c97f7303c3239e8'),
#  ObjectId('57929ed83c97f7303c3239e9'),
#  ObjectId('57929ed83c97f7303c3239ea'),
#  ObjectId('57929ed83c97f7303c3239eb'),
#  ObjectId('57929ed83c97f7303c3239ec'),
#  ObjectId('57929ed83c97f7303c3239ed'),
#  ObjectId('57929ed83c97f7303c3239ee'),
#  ObjectId('57929ed83c97f7303c3239ef'),
#  ObjectId('57929ed83c97f7303c3239f0'),
#  ObjectId('57929ed83c97f7303c3239f1'),
#  ObjectId('57929ed83c97f7303c3239f2'),
#  ObjectId('57929ed83c97f7303c3239f3'),
#  ObjectId('57929ed83c97f7303c3239f4'),
#  ObjectId('57929ed83c97f7303c3239f5'),
#  ObjectId('57929ed83c97f7303c3239f6'),
#  ObjectId('57929ed83c97f7303c3239f7'),
#  ObjectId('57929ed83c97f7303c3239f8'),
#  ObjectId('57929ed83c97f7303c3239f9'),
#  ObjectId('57929ed83c97f7303c3239fa'),
#  ObjectId('57929ed83c97f7303c3239fb'),
#  ObjectId('57929ed83c97f7303c3239fc'),
#  ObjectId('57929ed83c97f7303c3239fd'),
#  ObjectId('57929ed83c97f7303c3239fe'),
#  ObjectId('57929ed83c97f7303c3239ff'),
#  ObjectId('57929ed83c97f7303c323a00'),
#  ObjectId('57929ed83c97f7303c323a01'),
#  ObjectId('57929ed83c97f7303c323a02'),
#  ObjectId('57929ed83c97f7303c323a03'),
#  ObjectId('57929ed83c97f7303c323a04'),
#  ObjectId('57929ed83c97f7303c323a05'),
#  ObjectId('57929ed83c97f7303c323a06'),
#  ObjectId('57929ed83c97f7303c323a07'),
#  ObjectId('57929ed83c97f7303c323a08'),
#  ObjectId('57929ed83c97f7303c323a09'),
#  ObjectId('57929ed83c97f7303c323a0a'),
#  ObjectId('57929ed83c97f7303c323a0b'),
#  ObjectId('57929ed83c97f7303c323a0c'),
#  ObjectId('57929ed83c97f7303c323a0d'),
#  ObjectId('57929ed83c97f7303c323a0e'),
#  ObjectId('57929ed83c97f7303c323a0f'),
#  ObjectId('57929ed83c97f7303c323a10'),
#  ObjectId('57929ed83c97f7303c323a11'),
#  ObjectId('57929ed83c97f7303c323a12'),
#  ObjectId('57929ed83c97f7303c323a13'),
#  ObjectId('57929ed83c97f7303c323a14'),
#  ObjectId('57929ed83c97f7303c323a15'),
#  ObjectId('57929ed83c97f7303c323a16'),
#  ObjectId('57929ed83c97f7303c323a17'),
#  ObjectId('57929ed83c97f7303c323a18'),
#  ObjectId('57929ed83c97f7303c323a19'),
#  ObjectId('57929ed83c97f7303c323a1a'),
#  ObjectId('57929ed83c97f7303c323a1b'),
#  ObjectId('57929ed83c97f7303c323a1c'),
#  ObjectId('57929ed83c97f7303c323a1d'),
#  ObjectId('57929ed83c97f7303c323a1e'),
#  ObjectId('57929ed83c97f7303c323a1f'),
#  ObjectId('57929ed83c97f7303c323a20'),
#  ObjectId('57929ed83c97f7303c323a21'),
#  ObjectId('57929ed83c97f7303c323a22'),
#  ObjectId('57929ed83c97f7303c323a23'),
#  ObjectId('57929ed83c97f7303c323a24'),
#  ObjectId('57929ed83c97f7303c323a25'),
#  ObjectId('57929ed83c97f7303c323a26'),
#  ObjectId('57929ed83c97f7303c323a27'),
#  ObjectId('57929ed83c97f7303c323a28'),
#  ObjectId('57929ed83c97f7303c323a29'),
#  ObjectId('57929ed83c97f7303c323a2a'),
#  ObjectId('57929ed83c97f7303c323a2b'),
#  ObjectId('57929ed83c97f7303c323a2c'),
#  ObjectId('57929ed83c97f7303c323a2d'),
#  ObjectId('57929ed83c97f7303c323a2e'),
#  ObjectId('57929ed83c97f7303c323a2f'),
#  ObjectId('57929ed83c97f7303c323a30'),
#  ObjectId('57929ed83c97f7303c323a31'),
#  ObjectId('57929ed83c97f7303c323a32'),
#  ObjectId('57929ed83c97f7303c323a33'),
#  ObjectId('57929ed83c97f7303c323a34'),
#  ObjectId('57929ed83c97f7303c323a35'),
#  ObjectId('57929ed83c97f7303c323a36'),
#  ObjectId('57929ed83c97f7303c323a37'),
#  ObjectId('57929ed83c97f7303c323a38'),
#  ObjectId('57929ed83c97f7303c323a39'),
#  ObjectId('57929ed83c97f7303c323a3a'),
#  ObjectId('57929ed83c97f7303c323a3b'),
#  ObjectId('57929ed83c97f7303c323a3c'),
#  ObjectId('57929ed83c97f7303c323a3d'),
#  ObjectId('57929ed83c97f7303c323a3e'),
#  ObjectId('57929ed83c97f7303c323a3f'),
#  ObjectId('57929ed83c97f7303c323a40'),
#  ObjectId('57929ed83c97f7303c323a41'),
#  ObjectId('57929ed83c97f7303c323a42'),
#  ObjectId('57929ed83c97f7303c323a43'),
#  ObjectId('57929ed83c97f7303c323a44'),
#  ObjectId('57929ed83c97f7303c323a45'),
#  ObjectId('57929ed83c97f7303c323a46'),
#  ObjectId('57929ed83c97f7303c323a47'),
#  ObjectId('57929ed83c97f7303c323a48'),
#  ObjectId('57929ed83c97f7303c323a49'),
#  ObjectId('57929ed83c97f7303c323a4a'),
#  ObjectId('57929ed83c97f7303c323a4b'),
#  ObjectId('57929ed83c97f7303c323a4c'),
#  ObjectId('57929ed83c97f7303c323a4d'),
#  ObjectId('57929ed83c97f7303c323a4e'),
#  ObjectId('57929ed83c97f7303c323a4f'),
#  ObjectId('57929ed83c97f7303c323a50'),
#  ObjectId('57929ed83c97f7303c323a51'),
#  ObjectId('57929ed83c97f7303c323a52'),
#  ObjectId('57929ed83c97f7303c323a53'),
#  ObjectId('57929ed83c97f7303c323a54'),
#  ObjectId('57929ed83c97f7303c323a55'),
#  ObjectId('57929ed83c97f7303c323a56'),
#  ObjectId('57929ed83c97f7303c323a57'),
#  ObjectId('57929ed83c97f7303c323a58'),
#  ObjectId('57929ed83c97f7303c323a59'),
#  ObjectId('57929ed83c97f7303c323a5a'),
#  ObjectId('57929ed83c97f7303c323a5b'),
#  ObjectId('57929ed83c97f7303c323a5c'),
#  ObjectId('57929ed83c97f7303c323a5d'),
#  ObjectId('57929ed83c97f7303c323a5e'),
#  ObjectId('57929ed83c97f7303c323a5f'),
#  ObjectId('57929ed83c97f7303c323a60'),
#  ObjectId('57929ed83c97f7303c323a61'),
#  ObjectId('57929ed83c97f7303c323a62'),
#  ObjectId('57929ed83c97f7303c323a63'),
#  ObjectId('57929ed83c97f7303c323a64'),
#  ObjectId('57929ed83c97f7303c323a65'),
#  ObjectId('57929ed83c97f7303c323a66'),
#  ObjectId('57929ed83c97f7303c323a67'),
#  ObjectId('57929ed83c97f7303c323a68'),
#  ObjectId('57929ed83c97f7303c323a69'),
#  ObjectId('57929ed83c97f7303c323a6a'),
#  ObjectId('57929ed83c97f7303c323a6b'),
#  ObjectId('57929ed83c97f7303c323a6c'),
#  ObjectId('57929ed83c97f7303c323a6d'),
#  ObjectId('57929ed83c97f7303c323a6e'),
#  ObjectId('57929ed83c97f7303c323a6f'),
#  ObjectId('57929ed83c97f7303c323a70'),
#  ObjectId('57929ed83c97f7303c323a71'),
#  ObjectId('57929ed83c97f7303c323a72'),
#  ObjectId('57929ed83c97f7303c323a73'),
#  ObjectId('57929ed83c97f7303c323a74'),
#  ObjectId('57929ed83c97f7303c323a75'),
#  ObjectId('57929ed83c97f7303c323a76'),
#  ObjectId('57929ed83c97f7303c323a77'),
#  ObjectId('57929ed83c97f7303c323a78'),
#  ObjectId('57929ed83c97f7303c323a79'),
#  ObjectId('57929ed83c97f7303c323a7a'),
#  ObjectId('57929ed83c97f7303c323a7b'),
#  ObjectId('57929ed83c97f7303c323a7c'),
#  ObjectId('57929ed83c97f7303c323a7d'),
#  ObjectId('57929ed83c97f7303c323a7e'),
#  ObjectId('57929ed83c97f7303c323a7f'),
#  ObjectId('57929ed83c97f7303c323a80'),
#  ObjectId('57929ed83c97f7303c323a81'),
#  ObjectId('57929ed83c97f7303c323a82'),
#  ObjectId('57929ed83c97f7303c323a83'),
#  ObjectId('57929ed83c97f7303c323a84'),
#  ObjectId('57929ed83c97f7303c323a85'),
#  ObjectId('57929ed83c97f7303c323a86'),
#  ObjectId('57929ed83c97f7303c323a87'),
#  ObjectId('57929ed83c97f7303c323a88'),
#  ObjectId('57929ed83c97f7303c323a89'),
#  ObjectId('57929ed83c97f7303c323a8a'),
#  ObjectId('57929ed83c97f7303c323a8b'),
#  ObjectId('57929ed83c97f7303c323a8c'),
#  ObjectId('57929ed83c97f7303c323a8d'),
#  ObjectId('57929ed83c97f7303c323a8e'),
#  ObjectId('57929ed83c97f7303c323a8f'),
#  ObjectId('57929ed83c97f7303c323a90'),
#  ObjectId('57929ed83c97f7303c323a91'),
#  ObjectId('57929ed83c97f7303c323a92'),
#  ObjectId('57929ed83c97f7303c323a93'),
#  ObjectId('57929ed83c97f7303c323a94'),
#  ObjectId('57929ed83c97f7303c323a95'),
#  ObjectId('57929ed83c97f7303c323a96'),
#  ObjectId('57929ed83c97f7303c323a97'),
#  ObjectId('57929ed83c97f7303c323a98'),
#  ObjectId('57929ed83c97f7303c323a99'),
#  ObjectId('57929ed83c97f7303c323a9a'),
#  ObjectId('57929ed83c97f7303c323a9b'),
#  ObjectId('57929ed83c97f7303c323a9c'),
#  ObjectId('57929ed83c97f7303c323a9d'),
#  ObjectId('57929ed83c97f7303c323a9e'),
#  ObjectId('57929ed83c97f7303c323a9f'),
#  ObjectId('57929ed83c97f7303c323aa0'),
#  ObjectId('57929ed83c97f7303c323aa1'),
#  ObjectId('57929ed83c97f7303c323aa2'),
#  ObjectId('57929ed83c97f7303c323aa3'),
#  ObjectId('57929ed83c97f7303c323aa4'),
#  ObjectId('57929ed83c97f7303c323aa5'),
#  ObjectId('57929ed83c97f7303c323aa6'),
#  ObjectId('57929ed83c97f7303c323aa7'),
#  ObjectId('57929ed83c97f7303c323aa8'),
#  ObjectId('57929ed83c97f7303c323aa9'),
#  ObjectId('57929ed83c97f7303c323aaa'),
#  ObjectId('57929ed83c97f7303c323aab'),
#  ObjectId('57929ed83c97f7303c323aac'),
#  ObjectId('57929ed83c97f7303c323aad'),
#  ObjectId('57929ed83c97f7303c323aae'),
#  ObjectId('57929ed83c97f7303c323aaf'),
#  ObjectId('57929ed83c97f7303c323ab0'),
#  ObjectId('57929ed83c97f7303c323ab1'),
#  ObjectId('57929ed83c97f7303c323ab2'),
#  ObjectId('57929ed83c97f7303c323ab3'),
#  ObjectId('57929ed83c97f7303c323ab4'),
#  ObjectId('57929ed83c97f7303c323ab5'),
#  ObjectId('57929ed83c97f7303c323ab6'),
#  ObjectId('57929ed83c97f7303c323ab7'),
#  ObjectId('57929ed83c97f7303c323ab8'),
#  ObjectId('57929ed83c97f7303c323ab9'),
#  ObjectId('57929ed83c97f7303c323aba'),
#  ObjectId('57929ed83c97f7303c323abb'),
#  ObjectId('57929ed83c97f7303c323abc'),
#  ObjectId('57929ed83c97f7303c323abd'),
#  ObjectId('57929ed83c97f7303c323abe'),
#  ObjectId('57929ed83c97f7303c323abf'),
#  ObjectId('57929ed83c97f7303c323ac0'),
#  ObjectId('57929ed83c97f7303c323ac1'),
#  ObjectId('57929ed83c97f7303c323ac2'),
#  ObjectId('57929ed83c97f7303c323ac3'),
#  ObjectId('57929ed83c97f7303c323ac4'),
#  ObjectId('57929ed83c97f7303c323ac5'),
#  ObjectId('57929ed83c97f7303c323ac6'),
#  ObjectId('57929ed83c97f7303c323ac7'),
#  ObjectId('57929ed83c97f7303c323ac8'),
#  ObjectId('57929ed83c97f7303c323ac9'),
#  ObjectId('57929ed83c97f7303c323aca'),
#  ObjectId('57929ed83c97f7303c323acb'),
#  ObjectId('57929ed83c97f7303c323acc'),
#  ObjectId('57929ed83c97f7303c323acd'),
#  ObjectId('57929ed83c97f7303c323ace'),
#  ObjectId('57929ed83c97f7303c323acf'),
#  ObjectId('57929ed83c97f7303c323ad0'),
#  ObjectId('57929ed83c97f7303c323ad1'),
#  ObjectId('57929ed83c97f7303c323ad2'),
#  ObjectId('57929ed83c97f7303c323ad3'),
#  ObjectId('57929ed83c97f7303c323ad4'),
#  ObjectId('57929ed83c97f7303c323ad5'),
#  ObjectId('57929ed83c97f7303c323ad6'),
#  ObjectId('57929ed83c97f7303c323ad7'),
#  ObjectId('57929ed83c97f7303c323ad8'),
#  ObjectId('57929ed83c97f7303c323ad9'),
#  ObjectId('57929ed83c97f7303c323ada'),
#  ObjectId('57929ed83c97f7303c323adb'),
#  ObjectId('57929ed83c97f7303c323adc'),
#  ObjectId('57929ed83c97f7303c323add'),
#  ObjectId('57929ed83c97f7303c323ade'),
#  ObjectId('57929ed83c97f7303c323adf'),
#  ObjectId('57929ed83c97f7303c323ae0'),
#  ObjectId('57929ed83c97f7303c323ae1'),
#  ObjectId('57929ed83c97f7303c323ae2'),
#  ObjectId('57929ed83c97f7303c323ae3'),
#  ObjectId('57929ed83c97f7303c323ae4'),
#  ObjectId('57929ed83c97f7303c323ae5'),
#  ObjectId('57929ed83c97f7303c323ae6'),
#  ObjectId('57929ed83c97f7303c323ae7'),
#  ObjectId('57929ed83c97f7303c323ae8'),
#  ObjectId('57929ed83c97f7303c323ae9'),
#  ObjectId('57929ed83c97f7303c323aea'),
#  ObjectId('57929ed83c97f7303c323aeb'),
#  ObjectId('57929ed83c97f7303c323aec'),
#  ObjectId('57929ed83c97f7303c323aed'),
#  ObjectId('57929ed83c97f7303c323aee'),
#  ObjectId('57929ed83c97f7303c323aef'),
#  ObjectId('57929ed83c97f7303c323af0'),
#  ObjectId('57929ed83c97f7303c323af1'),
#  ObjectId('57929ed83c97f7303c323af2'),
#  ObjectId('57929ed83c97f7303c323af3'),
#  ObjectId('57929ed83c97f7303c323af4'),
#  ObjectId('57929ed83c97f7303c323af5'),
#  ObjectId('57929ed83c97f7303c323af6'),
#  ObjectId('57929ed83c97f7303c323af7'),
#  ObjectId('57929ed83c97f7303c323af8'),
#  ObjectId('57929ed83c97f7303c323af9'),
#  ObjectId('57929ed83c97f7303c323afa'),
#  ObjectId('57929ed83c97f7303c323afb'),
#  ObjectId('57929ed83c97f7303c323afc'),
#  ObjectId('57929ed83c97f7303c323afd'),
#  ObjectId('57929ed83c97f7303c323afe'),
#  ObjectId('57929ed83c97f7303c323aff'),
#  ObjectId('57929ed83c97f7303c323b00'),
#  ObjectId('57929ed83c97f7303c323b01'),
#  ObjectId('57929ed83c97f7303c323b02'),
#  ObjectId('57929ed83c97f7303c323b03'),
#  ObjectId('57929ed83c97f7303c323b04'),
#  ObjectId('57929ed83c97f7303c323b05'),
#  ObjectId('57929ed83c97f7303c323b06'),
#  ObjectId('57929ed83c97f7303c323b07'),
#  ObjectId('57929ed83c97f7303c323b08'),
#  ObjectId('57929ed83c97f7303c323b09'),
#  ObjectId('57929ed83c97f7303c323b0a'),
#  ObjectId('57929ed83c97f7303c323b0b'),
#  ObjectId('57929ed83c97f7303c323b0c'),
#  ObjectId('57929ed83c97f7303c323b0d'),
#  ObjectId('57929ed83c97f7303c323b0e'),
#  ObjectId('57929ed83c97f7303c323b0f'),
#  ObjectId('57929ed83c97f7303c323b10'),
#  ObjectId('57929ed83c97f7303c323b11'),
#  ObjectId('57929ed83c97f7303c323b12'),
#  ObjectId('57929ed83c97f7303c323b13'),
#  ObjectId('57929ed83c97f7303c323b14'),
#  ObjectId('57929ed83c97f7303c323b15'),
#  ObjectId('57929ed83c97f7303c323b16'),
#  ObjectId('57929ed83c97f7303c323b17'),
#  ObjectId('57929ed83c97f7303c323b18'),
#  ObjectId('57929ed83c97f7303c323b19'),
#  ObjectId('57929ed83c97f7303c323b1a'),
#  ObjectId('57929ed83c97f7303c323b1b'),
#  ObjectId('57929ed83c97f7303c323b1c'),
#  ObjectId('57929ed83c97f7303c323b1d'),
#  ObjectId('57929ed83c97f7303c323b1e'),
#  ObjectId('57929ed83c97f7303c323b1f'),
#  ObjectId('57929ed83c97f7303c323b20'),
#  ObjectId('57929ed83c97f7303c323b21'),
#  ObjectId('57929ed83c97f7303c323b22'),
#  ObjectId('57929ed83c97f7303c323b23'),
#  ObjectId('57929ed83c97f7303c323b24'),
#  ObjectId('57929ed83c97f7303c323b25'),
#  ObjectId('57929ed83c97f7303c323b26'),
#  ObjectId('57929ed83c97f7303c323b27'),
#  ObjectId('57929ed83c97f7303c323b28'),
#  ObjectId('57929ed83c97f7303c323b29'),
#  ObjectId('57929ed83c97f7303c323b2a'),
#  ObjectId('57929ed83c97f7303c323b2b'),
#  ObjectId('57929ed83c97f7303c323b2c'),
#  ObjectId('57929ed83c97f7303c323b2d'),
#  ObjectId('57929ed83c97f7303c323b2e'),
#  ObjectId('57929ed83c97f7303c323b2f'),
#  ObjectId('57929ed83c97f7303c323b30'),
#  ObjectId('57929ed83c97f7303c323b31'),
#  ObjectId('57929ed83c97f7303c323b32'),
#  ObjectId('57929ed83c97f7303c323b33'),
#  ObjectId('57929ed83c97f7303c323b34'),
#  ObjectId('57929ed83c97f7303c323b35'),
#  ObjectId('57929ed83c97f7303c323b36'),
#  ObjectId('57929ed83c97f7303c323b37'),
#  ObjectId('57929ed83c97f7303c323b38'),
#  ObjectId('57929ed83c97f7303c323b39'),
#  ObjectId('57929ed83c97f7303c323b3a'),
#  ObjectId('57929ed83c97f7303c323b3b'),
#  ObjectId('57929ed83c97f7303c323b3c'),
#  ObjectId('57929ed83c97f7303c323b3d'),
#  ObjectId('57929ed83c97f7303c323b3e'),
#  ObjectId('57929ed83c97f7303c323b3f'),
#  ObjectId('57929ed83c97f7303c323b40'),
#  ObjectId('57929ed83c97f7303c323b41'),
#  ObjectId('57929ed83c97f7303c323b42'),
#  ObjectId('57929ed83c97f7303c323b43'),
#  ObjectId('57929ed83c97f7303c323b44'),
#  ObjectId('57929ed83c97f7303c323b45'),
#  ObjectId('57929ed83c97f7303c323b46'),
#  ObjectId('57929ed83c97f7303c323b47'),
#  ObjectId('57929ed83c97f7303c323b48'),
#  ObjectId('57929ed83c97f7303c323b49'),
#  ObjectId('57929ed83c97f7303c323b4a'),
#  ObjectId('57929ed83c97f7303c323b4b'),
#  ObjectId('57929ed83c97f7303c323b4c'),
#  ObjectId('57929ed83c97f7303c323b4d'),
#  ObjectId('57929ed83c97f7303c323b4e'),
#  ObjectId('57929ed83c97f7303c323b4f'),
#  ObjectId('57929ed83c97f7303c323b50'),
#  ObjectId('57929ed83c97f7303c323b51'),
#  ObjectId('57929ed83c97f7303c323b52'),
#  ObjectId('57929ed83c97f7303c323b53'),
#  ObjectId('57929ed83c97f7303c323b54'),
#  ObjectId('57929ed83c97f7303c323b55'),
#  ObjectId('57929ed83c97f7303c323b56'),
#  ObjectId('57929ed83c97f7303c323b57'),
#  ObjectId('57929ed83c97f7303c323b58'),
#  ObjectId('57929ed83c97f7303c323b59'),
#  ObjectId('57929ed83c97f7303c323b5a'),
#  ObjectId('57929ed83c97f7303c323b5b'),
#  ObjectId('57929ed83c97f7303c323b5c'),
#  ObjectId('57929ed83c97f7303c323b5d'),
#  ObjectId('57929ed83c97f7303c323b5e'),
#  ObjectId('57929ed83c97f7303c323b5f'),
#  ObjectId('57929ed83c97f7303c323b60'),
#  ObjectId('57929ed83c97f7303c323b61'),
#  ObjectId('57929ed83c97f7303c323b62'),
#  ObjectId('57929ed83c97f7303c323b63'),
#  ObjectId('57929ed83c97f7303c323b64'),
#  ObjectId('57929ed83c97f7303c323b65'),
#  ObjectId('57929ed83c97f7303c323b66'),
#  ObjectId('57929ed83c97f7303c323b67'),
#  ObjectId('57929ed83c97f7303c323b68'),
#  ObjectId('57929ed83c97f7303c323b69'),
#  ObjectId('57929ed83c97f7303c323b6a'),
#  ObjectId('57929ed83c97f7303c323b6b'),
#  ObjectId('57929ed83c97f7303c323b6c'),
#  ObjectId('57929ed83c97f7303c323b6d'),
#  ObjectId('57929ed83c97f7303c323b6e'),
#  ObjectId('57929ed83c97f7303c323b6f'),
#  ObjectId('57929ed83c97f7303c323b70'),
#  ObjectId('57929ed83c97f7303c323b71'),
#  ObjectId('57929ed83c97f7303c323b72'),
#  ObjectId('57929ed83c97f7303c323b73'),
#  ObjectId('57929ed83c97f7303c323b74'),
#  ObjectId('57929ed83c97f7303c323b75'),
#  ObjectId('57929ed83c97f7303c323b76'),
#  ObjectId('57929ed83c97f7303c323b77'),
#  ObjectId('57929ed83c97f7303c323b78'),
#  ObjectId('57929ed83c97f7303c323b79'),
#  ObjectId('57929ed83c97f7303c323b7a'),
#  ObjectId('57929ed83c97f7303c323b7b'),
#  ObjectId('57929ed83c97f7303c323b7c'),
#  ObjectId('57929ed83c97f7303c323b7d'),
#  ObjectId('57929ed83c97f7303c323b7e'),
#  ObjectId('57929ed83c97f7303c323b7f'),
#  ObjectId('57929ed83c97f7303c323b80'),
#  ObjectId('57929ed83c97f7303c323b81'),
#  ObjectId('57929ed83c97f7303c323b82'),
#  ObjectId('57929ed83c97f7303c323b83'),
#  ObjectId('57929ed83c97f7303c323b84'),
#  ObjectId('57929ed83c97f7303c323b85'),
#  ObjectId('57929ed83c97f7303c323b86'),
#  ObjectId('57929ed83c97f7303c323b87'),
#  ObjectId('57929ed83c97f7303c323b88'),
#  ObjectId('57929ed83c97f7303c323b89'),
#  ObjectId('57929ed83c97f7303c323b8a'),
#  ObjectId('57929ed83c97f7303c323b8b'),
#  ObjectId('57929ed83c97f7303c323b8c'),
#  ObjectId('57929ed83c97f7303c323b8d'),
#  ObjectId('57929ed83c97f7303c323b8e'),
#  ObjectId('57929ed83c97f7303c323b8f'),
#  ObjectId('57929ed83c97f7303c323b90'),
#  ObjectId('57929ed83c97f7303c323b91'),
#  ObjectId('57929ed83c97f7303c323b92'),
#  ObjectId('57929ed83c97f7303c323b93'),
#  ObjectId('57929ed83c97f7303c323b94'),
#  ObjectId('57929ed83c97f7303c323b95'),
#  ObjectId('57929ed83c97f7303c323b96'),
#  ObjectId('57929ed83c97f7303c323b97'),
#  ObjectId('57929ed83c97f7303c323b98'),
#  ObjectId('57929ed83c97f7303c323b99'),
#  ObjectId('57929ed83c97f7303c323b9a'),
#  ObjectId('57929ed83c97f7303c323b9b'),
#  ObjectId('57929ed83c97f7303c323b9c'),
#  ObjectId('57929ed83c97f7303c323b9d'),
#  ObjectId('57929ed83c97f7303c323b9e'),
#  ObjectId('57929ed83c97f7303c323b9f'),
#  ObjectId('57929ed83c97f7303c323ba0'),
#  ObjectId('57929ed83c97f7303c323ba1'),
#  ObjectId('57929ed83c97f7303c323ba2'),
#  ObjectId('57929ed83c97f7303c323ba3'),
#  ObjectId('57929ed83c97f7303c323ba4'),
#  ObjectId('57929ed83c97f7303c323ba5'),
#  ObjectId('57929ed83c97f7303c323ba6'),
#  ObjectId('57929ed83c97f7303c323ba7'),
#  ObjectId('57929ed83c97f7303c323ba8'),
#  ObjectId('57929ed83c97f7303c323ba9'),
#  ObjectId('57929ed83c97f7303c323baa'),
#  ObjectId('57929ed83c97f7303c323bab'),
#  ObjectId('57929ed83c97f7303c323bac'),
#  ObjectId('57929ed83c97f7303c323bad'),
#  ObjectId('57929ed83c97f7303c323bae'),
#  ObjectId('57929ed83c97f7303c323baf'),
#  ObjectId('57929ed83c97f7303c323bb0'),
#  ObjectId('57929ed83c97f7303c323bb1'),
#  ObjectId('57929ed83c97f7303c323bb2'),
#  ObjectId('57929ed83c97f7303c323bb3'),
#  ObjectId('57929ed83c97f7303c323bb4'),
#  ObjectId('57929ed83c97f7303c323bb5'),
#  ObjectId('57929ed83c97f7303c323bb6'),
#  ObjectId('57929ed83c97f7303c323bb7'),
#  ObjectId('57929ed83c97f7303c323bb8'),
#  ObjectId('57929ed83c97f7303c323bb9'),
#  ObjectId('57929ed83c97f7303c323bba'),
#  ObjectId('57929ed83c97f7303c323bbb'),
#  ObjectId('57929ed83c97f7303c323bbc'),
#  ObjectId('57929ed83c97f7303c323bbd'),
#  ObjectId('57929ed83c97f7303c323bbe'),
#  ObjectId('57929ed83c97f7303c323bbf'),
#  ObjectId('57929ed83c97f7303c323bc0'),
#  ObjectId('57929ed83c97f7303c323bc1'),
#  ObjectId('57929ed83c97f7303c323bc2'),
#  ObjectId('57929ed83c97f7303c323bc3'),
#  ObjectId('57929ed83c97f7303c323bc4'),
#  ObjectId('57929ed83c97f7303c323bc5'),
#  ObjectId('57929ed83c97f7303c323bc6'),
#  ObjectId('57929ed83c97f7303c323bc7'),
#  ObjectId('57929ed83c97f7303c323bc8'),
#  ObjectId('57929ed83c97f7303c323bc9'),
#  ObjectId('57929ed83c97f7303c323bca'),
#  ObjectId('57929ed83c97f7303c323bcb'),
#  ObjectId('57929ed83c97f7303c323bcc'),
#  ObjectId('57929ed83c97f7303c323bcd'),
#  ObjectId('57929ed83c97f7303c323bce'),
#  ObjectId('57929ed83c97f7303c323bcf'),
#  ObjectId('57929ed83c97f7303c323bd0'),
#  ObjectId('57929ed83c97f7303c323bd1'),
#  ObjectId('57929ed83c97f7303c323bd2'),
#  ObjectId('57929ed83c97f7303c323bd3'),
#  ObjectId('57929ed83c97f7303c323bd4'),
#  ObjectId('57929ed83c97f7303c323bd5'),
#  ObjectId('57929ed83c97f7303c323bd6'),
#  ObjectId('57929ed83c97f7303c323bd7'),
#  ObjectId('57929ed83c97f7303c323bd8'),
#  ObjectId('57929ed83c97f7303c323bd9'),
#  ObjectId('57929ed83c97f7303c323bda'),
#  ObjectId('57929ed83c97f7303c323bdb'),
#  ObjectId('57929ed83c97f7303c323bdc'),
#  ObjectId('57929ed83c97f7303c323bdd'),
#  ObjectId('57929ed83c97f7303c323bde'),
#  ObjectId('57929ed83c97f7303c323bdf'),
#  ObjectId('57929ed83c97f7303c323be0'),
#  ObjectId('57929ed83c97f7303c323be1'),
#  ObjectId('57929ed83c97f7303c323be2'),
#  ObjectId('57929ed83c97f7303c323be3'),
#  ObjectId('57929ed83c97f7303c323be4'),
#  ObjectId('57929ed83c97f7303c323be5'),
#  ObjectId('57929ed83c97f7303c323be6'),
#  ObjectId('57929ed83c97f7303c323be7'),
#  ObjectId('57929ed83c97f7303c323be8'),
#  ObjectId('57929ed83c97f7303c323be9'),
#  ObjectId('57929ed83c97f7303c323bea'),
#  ObjectId('57929ed83c97f7303c323beb'),
#  ObjectId('57929ed83c97f7303c323bec'),
#  ObjectId('57929ed83c97f7303c323bed'),
#  ObjectId('57929ed83c97f7303c323bee'),
#  ObjectId('57929ed83c97f7303c323bef'),
#  ObjectId('57929ed83c97f7303c323bf0'),
#  ObjectId('57929ed83c97f7303c323bf1'),
#  ObjectId('57929ed83c97f7303c323bf2'),
#  ObjectId('57929ed83c97f7303c323bf3'),
#  ObjectId('57929ed83c97f7303c323bf4'),
#  ObjectId('57929ed83c97f7303c323bf5'),
#  ObjectId('57929ed83c97f7303c323bf6'),
#  ObjectId('57929ed83c97f7303c323bf7'),
#  ObjectId('57929ed83c97f7303c323bf8'),
#  ObjectId('57929ed83c97f7303c323bf9'),
#  ObjectId('57929ed83c97f7303c323bfa'),
#  ObjectId('57929ed83c97f7303c323bfb'),
#  ObjectId('57929ed83c97f7303c323bfc'),
#  ObjectId('57929ed83c97f7303c323bfd'),
#  ObjectId('57929ed83c97f7303c323bfe'),
#  ObjectId('57929ed83c97f7303c323bff'),
#  ObjectId('57929ed83c97f7303c323c00'),
#  ObjectId('57929ed83c97f7303c323c01'),
#  ObjectId('57929ed83c97f7303c323c02'),
#  ObjectId('57929ed83c97f7303c323c03'),
#  ObjectId('57929ed83c97f7303c323c04'),
#  ObjectId('57929ed83c97f7303c323c05'),
#  ObjectId('57929ed83c97f7303c323c06'),
#  ObjectId('57929ed83c97f7303c323c07'),
#  ObjectId('57929ed83c97f7303c323c08'),
#  ObjectId('57929ed83c97f7303c323c09'),
#  ObjectId('57929ed83c97f7303c323c0a'),
#  ObjectId('57929ed83c97f7303c323c0b'),
#  ObjectId('57929ed83c97f7303c323c0c'),
#  ObjectId('57929ed83c97f7303c323c0d'),
#  ObjectId('57929ed83c97f7303c323c0e'),
#  ObjectId('57929ed83c97f7303c323c0f'),
#  ObjectId('57929ed83c97f7303c323c10'),
#  ObjectId('57929ed83c97f7303c323c11'),
#  ObjectId('57929ed83c97f7303c323c12'),
#  ObjectId('57929ed83c97f7303c323c13'),
#  ObjectId('57929ed83c97f7303c323c14'),
#  ObjectId('57929ed83c97f7303c323c15'),
#  ObjectId('57929ed83c97f7303c323c16'),
#  ObjectId('57929ed83c97f7303c323c17'),
#  ObjectId('57929ed83c97f7303c323c18'),
#  ObjectId('57929ed83c97f7303c323c19'),
#  ObjectId('57929ed83c97f7303c323c1a'),
#  ObjectId('57929ed83c97f7303c323c1b'),
#  ObjectId('57929ed83c97f7303c323c1c'),
#  ObjectId('57929ed83c97f7303c323c1d'),
#  ObjectId('57929ed83c97f7303c323c1e'),
#  ObjectId('57929ed83c97f7303c323c1f'),
#  ObjectId('57929ed83c97f7303c323c20'),
#  ObjectId('57929ed83c97f7303c323c21'),
#  ObjectId('57929ed83c97f7303c323c22'),
#  ObjectId('57929ed83c97f7303c323c23'),
#  ObjectId('57929ed83c97f7303c323c24'),
#  ObjectId('57929ed83c97f7303c323c25'),
#  ObjectId('57929ed83c97f7303c323c26'),
#  ObjectId('57929ed83c97f7303c323c27'),
#  ObjectId('57929ed83c97f7303c323c28'),
#  ObjectId('57929ed83c97f7303c323c29'),
#  ObjectId('57929ed83c97f7303c323c2a'),
#  ObjectId('57929ed83c97f7303c323c2b'),
#  ObjectId('57929ed83c97f7303c323c2c'),
#  ObjectId('57929ed83c97f7303c323c2d'),
#  ObjectId('57929ed83c97f7303c323c2e'),
#  ObjectId('57929ed83c97f7303c323c2f'),
#  ObjectId('57929ed83c97f7303c323c30'),
#  ObjectId('57929ed83c97f7303c323c31'),
#  ObjectId('57929ed83c97f7303c323c32'),
#  ObjectId('57929ed83c97f7303c323c33'),
#  ObjectId('57929ed83c97f7303c323c34'),
#  ObjectId('57929ed83c97f7303c323c35'),
#  ObjectId('57929ed83c97f7303c323c36'),
#  ObjectId('57929ed83c97f7303c323c37'),
#  ObjectId('57929ed83c97f7303c323c38'),
#  ObjectId('57929ed83c97f7303c323c39'),
#  ObjectId('57929ed83c97f7303c323c3a'),
#  ObjectId('57929ed83c97f7303c323c3b'),
#  ObjectId('57929ed83c97f7303c323c3c'),
#  ObjectId('57929ed83c97f7303c323c3d'),
#  ObjectId('57929ed83c97f7303c323c3e'),
#  ObjectId('57929ed83c97f7303c323c3f'),
#  ObjectId('57929ed83c97f7303c323c40'),
#  ObjectId('57929ed83c97f7303c323c41'),
#  ObjectId('57929ed83c97f7303c323c42'),
#  ObjectId('57929ed83c97f7303c323c43'),
#  ObjectId('57929ed83c97f7303c323c44'),
#  ObjectId('57929ed83c97f7303c323c45'),
#  ObjectId('57929ed83c97f7303c323c46'),
#  ObjectId('57929ed83c97f7303c323c47'),
#  ObjectId('57929ed83c97f7303c323c48'),
#  ObjectId('57929ed83c97f7303c323c49'),
#  ObjectId('57929ed83c97f7303c323c4a'),
#  ObjectId('57929ed83c97f7303c323c4b'),
#  ObjectId('57929ed83c97f7303c323c4c'),
#  ObjectId('57929ed83c97f7303c323c4d'),
#  ObjectId('57929ed83c97f7303c323c4e'),
#  ObjectId('57929ed83c97f7303c323c4f'),
#  ObjectId('57929ed83c97f7303c323c50'),
#  ObjectId('57929ed83c97f7303c323c51'),
#  ObjectId('57929ed83c97f7303c323c52'),
#  ObjectId('57929ed83c97f7303c323c53'),
#  ObjectId('57929ed83c97f7303c323c54'),
#  ObjectId('57929ed83c97f7303c323c55'),
#  ObjectId('57929ed83c97f7303c323c56'),
#  ObjectId('57929ed83c97f7303c323c57'),
#  ObjectId('57929ed83c97f7303c323c58'),
#  ObjectId('57929ed83c97f7303c323c59'),
#  ObjectId('57929ed83c97f7303c323c5a'),
#  ObjectId('57929ed83c97f7303c323c5b'),
#  ObjectId('57929ed83c97f7303c323c5c'),
#  ObjectId('57929ed83c97f7303c323c5d'),
#  ObjectId('57929ed83c97f7303c323c5e'),
#  ObjectId('57929ed83c97f7303c323c5f'),
#  ObjectId('57929ed83c97f7303c323c60'),
#  ObjectId('57929ed83c97f7303c323c61'),
#  ObjectId('57929ed83c97f7303c323c62'),
#  ObjectId('57929ed83c97f7303c323c63'),
#  ObjectId('57929ed83c97f7303c323c64'),
#  ObjectId('57929ed83c97f7303c323c65'),
#  ObjectId('57929ed83c97f7303c323c66'),
#  ObjectId('57929ed83c97f7303c323c67'),
#  ObjectId('57929ed83c97f7303c323c68'),
#  ObjectId('57929ed83c97f7303c323c69'),
#  ObjectId('57929ed83c97f7303c323c6a'),
#  ObjectId('57929ed83c97f7303c323c6b'),
#  ObjectId('57929ed83c97f7303c323c6c'),
#  ObjectId('57929ed83c97f7303c323c6d'),
#  ObjectId('57929ed83c97f7303c323c6e'),
#  ObjectId('57929ed83c97f7303c323c6f'),
#  ObjectId('57929ed83c97f7303c323c70'),
#  ObjectId('57929ed83c97f7303c323c71'),
#  ObjectId('57929ed83c97f7303c323c72'),
#  ObjectId('57929ed83c97f7303c323c73'),
#  ObjectId('57929ed83c97f7303c323c74'),
#  ObjectId('57929ed83c97f7303c323c75'),
#  ObjectId('57929ed83c97f7303c323c76'),
#  ObjectId('57929ed83c97f7303c323c77'),
#  ObjectId('57929ed83c97f7303c323c78'),
#  ObjectId('57929ed83c97f7303c323c79'),
#  ObjectId('57929ed83c97f7303c323c7a'),
#  ObjectId('57929ed83c97f7303c323c7b'),
#  ObjectId('57929ed83c97f7303c323c7c'),
#  ObjectId('57929ed83c97f7303c323c7d'),
#  ObjectId('57929ed83c97f7303c323c7e'),
#  ObjectId('57929ed83c97f7303c323c7f'),
#  ObjectId('57929ed83c97f7303c323c80'),
#  ObjectId('57929ed83c97f7303c323c81'),
#  ObjectId('57929ed83c97f7303c323c82'),
#  ObjectId('57929ed83c97f7303c323c83'),
#  ObjectId('57929ed83c97f7303c323c84'),
#  ObjectId('57929ed83c97f7303c323c85'),
#  ObjectId('57929ed83c97f7303c323c86'),
#  ObjectId('57929ed83c97f7303c323c87'),
#  ObjectId('57929ed83c97f7303c323c88'),
#  ObjectId('57929ed83c97f7303c323c89'),
#  ObjectId('57929ed83c97f7303c323c8a'),
#  ObjectId('57929ed83c97f7303c323c8b'),
#  ObjectId('57929ed83c97f7303c323c8c'),
#  ObjectId('57929ed83c97f7303c323c8d'),
#  ObjectId('57929ed83c97f7303c323c8e'),
#  ObjectId('57929ed83c97f7303c323c8f'),
#  ObjectId('57929ed83c97f7303c323c90'),
#  ObjectId('57929ed83c97f7303c323c91'),
#  ObjectId('57929ed83c97f7303c323c92'),
#  ObjectId('57929ed83c97f7303c323c93'),
#  ObjectId('57929ed83c97f7303c323c94'),
#  ObjectId('57929ed83c97f7303c323c95'),
#  ObjectId('57929ed83c97f7303c323c96'),
#  ObjectId('57929ed83c97f7303c323c97'),
#  ObjectId('57929ed83c97f7303c323c98'),
#  ObjectId('57929ed83c97f7303c323c99'),
#  ObjectId('57929ed83c97f7303c323c9a'),
#  ObjectId('57929ed83c97f7303c323c9b'),
#  ObjectId('57929ed83c97f7303c323c9c'),
#  ObjectId('57929ed83c97f7303c323c9d'),
#  ObjectId('57929ed83c97f7303c323c9e'),
#  ObjectId('57929ed83c97f7303c323c9f'),
#  ObjectId('57929ed83c97f7303c323ca0'),
#  ObjectId('57929ed83c97f7303c323ca1'),
#  ObjectId('57929ed83c97f7303c323ca2'),
#  ObjectId('57929ed83c97f7303c323ca3'),
#  ObjectId('57929ed83c97f7303c323ca4'),
#  ObjectId('57929ed83c97f7303c323ca5'),
#  ObjectId('57929ed83c97f7303c323ca6'),
#  ObjectId('57929ed83c97f7303c323ca7'),
#  ObjectId('57929ed83c97f7303c323ca8'),
#  ObjectId('57929ed83c97f7303c323ca9'),
#  ObjectId('57929ed83c97f7303c323caa'),
#  ObjectId('57929ed83c97f7303c323cab'),
#  ObjectId('57929ed83c97f7303c323cac'),
#  ObjectId('57929ed83c97f7303c323cad'),
#  ObjectId('57929ed83c97f7303c323cae'),
#  ObjectId('57929ed83c97f7303c323caf'),
#  ObjectId('57929ed83c97f7303c323cb0'),
#  ObjectId('57929ed83c97f7303c323cb1'),
#  ObjectId('57929ed83c97f7303c323cb2'),
#  ObjectId('57929ed83c97f7303c323cb3'),
#  ObjectId('57929ed83c97f7303c323cb4'),
#  ObjectId('57929ed83c97f7303c323cb5'),
#  ObjectId('57929ed83c97f7303c323cb6'),
#  ObjectId('57929ed83c97f7303c323cb7'),
#  ObjectId('57929ed83c97f7303c323cb8'),
#  ObjectId('57929ed83c97f7303c323cb9'),
#  ObjectId('57929ed83c97f7303c323cba'),
#  ObjectId('57929ed83c97f7303c323cbb'),
#  ObjectId('57929ed83c97f7303c323cbc'),
#  ObjectId('57929ed83c97f7303c323cbd'),
#  ObjectId('57929ed83c97f7303c323cbe'),
#  ObjectId('57929ed83c97f7303c323cbf'),
#  ObjectId('57929ed83c97f7303c323cc0'),
#  ObjectId('57929ed83c97f7303c323cc1'),
#  ObjectId('57929ed83c97f7303c323cc2'),
#  ObjectId('57929ed83c97f7303c323cc3'),
#  ObjectId('57929ed83c97f7303c323cc4'),
#  ObjectId('57929ed83c97f7303c323cc5'),
#  ObjectId('57929ed83c97f7303c323cc6'),
#  ObjectId('57929ed83c97f7303c323cc7'),
#  ObjectId('57929ed83c97f7303c323cc8'),
#  ObjectId('57929ed83c97f7303c323cc9'),
#  ObjectId('57929ed83c97f7303c323cca'),
#  ObjectId('57929ed83c97f7303c323ccb'),
#  ObjectId('57929ed83c97f7303c323ccc'),
#  ObjectId('57929ed83c97f7303c323ccd'),
#  ObjectId('57929ed83c97f7303c323cce'),
#  ObjectId('57929ed83c97f7303c323ccf'),
#  ObjectId('57929ed83c97f7303c323cd0'),
#  ObjectId('57929ed83c97f7303c323cd1'),
#  ObjectId('57929ed83c97f7303c323cd2'),
#  ObjectId('57929ed83c97f7303c323cd3'),
#  ObjectId('57929ed83c97f7303c323cd4'),
#  ObjectId('57929ed83c97f7303c323cd5'),
#  ObjectId('57929ed83c97f7303c323cd6'),
#  ObjectId('57929ed83c97f7303c323cd7'),
#  ObjectId('57929ed83c97f7303c323cd8'),
#  ObjectId('57929ed83c97f7303c323cd9'),
#  ObjectId('57929ed83c97f7303c323cda'),
#  ObjectId('57929ed83c97f7303c323cdb'),
#  ObjectId('57929ed83c97f7303c323cdc'),
#  ObjectId('57929ed83c97f7303c323cdd'),
#  ObjectId('57929ed83c97f7303c323cde'),
#  ObjectId('57929ed83c97f7303c323cdf'),
#  ObjectId('57929ed83c97f7303c323ce0'),
#  ObjectId('57929ed83c97f7303c323ce1'),
#  ObjectId('57929ed83c97f7303c323ce2'),
#  ObjectId('57929ed83c97f7303c323ce3'),
#  ObjectId('57929ed83c97f7303c323ce4'),
#  ObjectId('57929ed83c97f7303c323ce5'),
#  ObjectId('57929ed83c97f7303c323ce6'),
#  ObjectId('57929ed83c97f7303c323ce7'),
#  ObjectId('57929ed83c97f7303c323ce8'),
#  ObjectId('57929ed83c97f7303c323ce9'),
#  ObjectId('57929ed83c97f7303c323cea'),
#  ObjectId('57929ed83c97f7303c323ceb'),
#  ObjectId('57929ed83c97f7303c323cec'),
#  ObjectId('57929ed83c97f7303c323ced'),
#  ObjectId('57929ed83c97f7303c323cee'),
#  ObjectId('57929ed83c97f7303c323cef'),
#  ObjectId('57929ed83c97f7303c323cf0'),
#  ObjectId('57929ed83c97f7303c323cf1'),
#  ObjectId('57929ed83c97f7303c323cf2'),
#  ObjectId('57929ed83c97f7303c323cf3'),
#  ObjectId('57929ed83c97f7303c323cf4'),
#  ObjectId('57929ed83c97f7303c323cf5'),
#  ObjectId('57929ed83c97f7303c323cf6'),
#  ObjectId('57929ed83c97f7303c323cf7'),
#  ObjectId('57929ed83c97f7303c323cf8'),
#  ObjectId('57929ed83c97f7303c323cf9'),
#  ObjectId('57929ed83c97f7303c323cfa'),
#  ObjectId('57929ed83c97f7303c323cfb'),
#  ObjectId('57929ed83c97f7303c323cfc'),
#  ObjectId('57929ed83c97f7303c323cfd'),
#  ObjectId('57929ed83c97f7303c323cfe'),
#  ObjectId('57929ed83c97f7303c323cff'),
#  ObjectId('57929ed83c97f7303c323d00'),
#  ObjectId('57929ed83c97f7303c323d01'),
#  ObjectId('57929ed83c97f7303c323d02'),
#  ObjectId('57929ed83c97f7303c323d03'),
#  ObjectId('57929ed83c97f7303c323d04'),
#  ObjectId('57929ed83c97f7303c323d05'),
#  ObjectId('57929ed83c97f7303c323d06'),
#  ObjectId('57929ed83c97f7303c323d07'),
#  ObjectId('57929ed83c97f7303c323d08'),
#  ObjectId('57929ed83c97f7303c323d09'),
#  ObjectId('57929ed83c97f7303c323d0a'),
#  ObjectId('57929ed83c97f7303c323d0b'),
#  ObjectId('57929ed83c97f7303c323d0c'),
#  ObjectId('57929ed83c97f7303c323d0d'),
#  ObjectId('57929ed83c97f7303c323d0e'),
#  ObjectId('57929ed83c97f7303c323d0f'),
#  ObjectId('57929ed83c97f7303c323d10'),
#  ObjectId('57929ed83c97f7303c323d11'),
#  ObjectId('57929ed83c97f7303c323d12'),
#  ObjectId('57929ed83c97f7303c323d13'),
#  ObjectId('57929ed83c97f7303c323d14'),
#  ObjectId('57929ed83c97f7303c323d15'),
#  ObjectId('57929ed83c97f7303c323d16'),
#  ObjectId('57929ed83c97f7303c323d17'),
#  ObjectId('57929ed83c97f7303c323d18'),
#  ObjectId('57929ed83c97f7303c323d19'),
#  ObjectId('57929ed83c97f7303c323d1a'),
#  ObjectId('57929ed83c97f7303c323d1b'),
#  ObjectId('57929ed83c97f7303c323d1c'),
#  ObjectId('57929ed83c97f7303c323d1d'),
#  ObjectId('57929ed83c97f7303c323d1e'),
#  ObjectId('57929ed83c97f7303c323d1f'),
#  ObjectId('57929ed83c97f7303c323d20'),
#  ObjectId('57929ed83c97f7303c323d21'),
#  ObjectId('57929ed83c97f7303c323d22'),
#  ObjectId('57929ed83c97f7303c323d23'),
#  ObjectId('57929ed83c97f7303c323d24'),
#  ObjectId('57929ed83c97f7303c323d25'),
#  ObjectId('57929ed83c97f7303c323d26'),
#  ObjectId('57929ed83c97f7303c323d27'),
#  ObjectId('57929ed83c97f7303c323d28'),
#  ObjectId('57929ed83c97f7303c323d29'),
#  ObjectId('57929ed83c97f7303c323d2a'),
#  ObjectId('57929ed83c97f7303c323d2b'),
#  ObjectId('57929ed83c97f7303c323d2c'),
#  ObjectId('57929ed83c97f7303c323d2d'),
#  ObjectId('57929ed83c97f7303c323d2e'),
#  ObjectId('57929ed83c97f7303c323d2f'),
#  ObjectId('57929ed83c97f7303c323d30'),
#  ObjectId('57929ed83c97f7303c323d31'),
#  ObjectId('57929ed83c97f7303c323d32'),
#  ObjectId('57929ed83c97f7303c323d33'),
#  ObjectId('57929ed83c97f7303c323d34'),
#  ObjectId('57929ed83c97f7303c323d35'),
#  ObjectId('57929ed83c97f7303c323d36'),
#  ObjectId('57929ed83c97f7303c323d37'),
#  ObjectId('57929ed83c97f7303c323d38'),
#  ObjectId('57929ed83c97f7303c323d39'),
#  ObjectId('57929ed83c97f7303c323d3a'),
#  ObjectId('57929ed83c97f7303c323d3b'),
#  ObjectId('57929ed83c97f7303c323d3c'),
#  ObjectId('57929ed83c97f7303c323d3d'),
#  ObjectId('57929ed83c97f7303c323d3e'),
#  ObjectId('57929ed83c97f7303c323d3f'),
#  ObjectId('57929ed83c97f7303c323d40'),
#  ObjectId('57929ed83c97f7303c323d41'),
#  ObjectId('57929ed83c97f7303c323d42'),
#  ObjectId('57929ed83c97f7303c323d43'),
#  ObjectId('57929ed83c97f7303c323d44'),
#  ObjectId('57929ed83c97f7303c323d45'),
#  ObjectId('57929ed83c97f7303c323d46'),
#  ObjectId('57929ed83c97f7303c323d47'),
#  ObjectId('57929ed83c97f7303c323d48'),
#  ObjectId('57929ed83c97f7303c323d49'),
#  ObjectId('57929ed83c97f7303c323d4a'),
#  ObjectId('57929ed83c97f7303c323d4b'),
#  ObjectId('57929ed83c97f7303c323d4c'),
#  ObjectId('57929ed83c97f7303c323d4d'),
#  ObjectId('57929ed83c97f7303c323d4e'),
#  ObjectId('57929ed83c97f7303c323d4f'),
#  ObjectId('57929ed83c97f7303c323d50'),
#  ObjectId('57929ed83c97f7303c323d51'),
#  ObjectId('57929ed83c97f7303c323d52'),
#  ObjectId('57929ed83c97f7303c323d53'),
#  ObjectId('57929ed83c97f7303c323d54'),
#  ObjectId('57929ed83c97f7303c323d55'),
#  ObjectId('57929ed83c97f7303c323d56'),
#  ObjectId('57929ed83c97f7303c323d57'),
#  ObjectId('57929ed83c97f7303c323d58'),
#  ObjectId('57929ed83c97f7303c323d59'),
#  ObjectId('57929ed83c97f7303c323d5a'),
#  ObjectId('57929ed83c97f7303c323d5b'),
#  ObjectId('57929ed83c97f7303c323d5c'),
#  ObjectId('57929ed83c97f7303c323d5d'),
#  ObjectId('57929ed83c97f7303c323d5e'),
#  ObjectId('57929ed83c97f7303c323d5f'),
#  ObjectId('57929ed83c97f7303c323d60'),
#  ObjectId('57929ed83c97f7303c323d61'),
#  ObjectId('57929ed83c97f7303c323d62'),
#  ObjectId('57929ed83c97f7303c323d63'),
#  ObjectId('57929ed83c97f7303c323d64'),
#  ObjectId('57929ed83c97f7303c323d65'),
#  ObjectId('57929ed83c97f7303c323d66'),
#  ObjectId('57929ed83c97f7303c323d67'),
#  ObjectId('57929ed83c97f7303c323d68'),
#  ObjectId('57929ed83c97f7303c323d69'),
#  ObjectId('57929ed83c97f7303c323d6a'),
#  ObjectId('57929ed83c97f7303c323d6b'),
#  ObjectId('57929ed83c97f7303c323d6c'),
#  ObjectId('57929ed83c97f7303c323d6d'),
#  ObjectId('57929ed83c97f7303c323d6e'),
#  ObjectId('57929ed83c97f7303c323d6f'),
#  ObjectId('57929ed83c97f7303c323d70'),
#  ObjectId('57929ed83c97f7303c323d71'),
#  ObjectId('57929ed83c97f7303c323d72'),
#  ObjectId('57929ed83c97f7303c323d73'),
#  ObjectId('57929ed83c97f7303c323d74'),
#  ObjectId('57929ed83c97f7303c323d75'),
#  ObjectId('57929ed83c97f7303c323d76'),
#  ObjectId('57929ed83c97f7303c323d77'),
#  ObjectId('57929ed83c97f7303c323d78'),
#  ObjectId('57929ed83c97f7303c323d79'),
#  ObjectId('57929ed83c97f7303c323d7a'),
#  ObjectId('57929ed83c97f7303c323d7b'),
#  ObjectId('57929ed83c97f7303c323d7c'),
#  ObjectId('57929ed83c97f7303c323d7d'),
#  ObjectId('57929ed83c97f7303c323d7e'),
#  ObjectId('57929ed83c97f7303c323d7f'),
#  ...]

# %% [markdown]
# ## City names in the Dataset

# %% [markdown]
# ### Checking if the city name is correct in the dataset

# %%
city = db.St_Monica_CA.aggregate( [ 
    { "$match" : { "address.city" : { "$exists" : 1} } }, 
    { "$group" : { "_id" : "$address.city", "count" : { "$sum" : 1} } },  
    { "$sort" : { "count" : -1}},
      ])
print(list(city))
# Out:
# [{u'count': 92, u'_id': u'Santa Monica'}, {u'count': 34, u'_id': u'Los Angeles'}, {u'count': 19, u'_id': u'Marina Del Rey CA'}, {u'count': 13, u'_id': u'Marina Del Rey'}, {u'count': 10, u'_id': u'Venice'}, {u'count': 7, u'_id': u'Marina del Rey'}, {u'count': 3, u'_id': u'Los Angeles-Venice'}, {u'count': 2, u'_id': u'West Los Angeles'}, {u'count': 1, u'_id': u'Venice CA'}, {u'count': 1, u'_id': u'Marina del Ray'}, {u'count': 1, u'_id': u'santa Monica'}, {u'count': 1, u'_id': u'Pacific Palisades'}]

# %% [markdown]
# # Updating City Names

# %%
db.St_Monica_CA.update_many(
    {"address.city": {"$in": [
        "santa Monica",
        "Los Angeles",
        "West Los Angeles" 
    ]}}, 
    {"$set": {"address.city": "Santa Monica"}}, 
    upsert = True
)

# %%
db.St_Monica_CA.update_many(
    {"address.city": {"$in": [
        "Marina Del Rey CA",
        "Marina del Rey ",
        "Marina del Ray" 
    ]}}, 
    {"$set": {"address.city": "Santa Monica"}}, 
    upsert = True
)

# %%
db.St_Monica_CA.update_many(
    {"address.city": {"$in": [
        "Los Angeles-Venice",
        "Venice CA "
         ]}}, 
    {"$set": {"address.city": "Santa Monica"}}, 
    upsert = True
)

# %% [markdown]
# ## Checking if city name is updated

# %%
city_updated = db.St_Monica_CA.aggregate( [ 
    { "$match" : { "address.city" : { "$exists" : 1} } }, 
    { "$group" : { "_id" : "$address.city", "count" : { "$sum" : 1} } },  
    { "$sort" : { "count" : -1}},
      ])
print(list(city_updated))
# Out:
# [{u'count': 129, u'_id': u'Santa Monica'}, {u'count': 40, u'_id': u'Marina Del Rey'}, {u'count': 14, u'_id': u'Venice'}, {u'count': 1, u'_id': u'Pacific Palisades'}]

# %% [markdown]
# ## Analyzing Dataset

# %% [markdown]
# #### The data size in OSM and Json Format

# %%
import os
print 'Size of the OSM file = {} MB'.format(os.path.getsize(SM_data)/1.0e6) 
print 'Size of JSON file = {} MB'.format(os.path.getsize(SM_data + ".json")/1.0e6)
# Out:
# Size of the OSM file = 111.134183 MB
# Size of JSON file = 125.765236 MB

# %% [markdown]
# ## Number of Documents

# %%
db.St_Monica_CA.find().count()
# Out:
# 537949

# %% [markdown]
# ## Number of Nodes

# %%
db.St_Monica_CA.find({"type":"node"}).count()
# Out:
# 486071

# %%
db.St_Monica_CA.find({"type":"way"}).count()
# Out:
# 51872

# %% [markdown]
# ## Number of unique users

# %%
len(db.St_Monica_CA.distinct('created.user'))
# Out:
# 341

# %% [markdown]
# ## Amenities in Santa Monica

# %%
amenity = db.St_Monica_CA.aggregate([{'$match': {'amenity': {'$exists': 1}}}, \
                                {'$group': {'_id': '$amenity', \
                                            'count': {'$sum': 1}}}, \
                                {'$sort': {'count': -1}}, \
                                {'$limit': 10}])
print(list(amenity))
# Out:
# [{u'count': 176, u'_id': u'parking'}, {u'count': 86, u'_id': u'restaurant'}, {u'count': 83, u'_id': u'bicycle_rental'}, {u'count': 57, u'_id': u'school'}, {u'count': 50, u'_id': u'place_of_worship'}, {u'count': 42, u'_id': u'cafe'}, {u'count': 41, u'_id': u'drinking_water'}, {u'count': 23, u'_id': u'fast_food'}, {u'count': 20, u'_id': u'toilets'}, {u'count': 17, u'_id': u'fuel'}]

# %% [markdown]
# ## Types of Cuisines

# %%
cuisine = db.St_Monica_CA.aggregate([{"$match":{"amenity":{"$exists":1},
                                 "amenity":"restaurant",}},      
                      {"$group":{"_id":{"Food":"$cuisine"},
                                 "count":{"$sum":1}}},
                      {"$project":{"_id":0,
                                  "Food":"$_id.Food",
                                  "Count":"$count"}},
                      {"$sort":{"Count":-1}}, 
                      ])
print(list(cuisine))
# Out:
# [{u'Food': None, u'Count': 43}, {u'Food': u'american', u'Count': 9}, {u'Food': u'mexican', u'Count': 5}, {u'Food': u'italian', u'Count': 5}, {u'Food': u'burger', u'Count': 4}, {u'Food': u'regional', u'Count': 2}, {u'Food': u'thai', u'Count': 2}, {u'Food': u'steakhouse,_italian,_mediterranean', u'Count': 2}, {u'Food': u'sandwich', u'Count': 2}, {u'Food': u'pizza', u'Count': 2}, {u'Food': u'indian', u'Count': 1}, {u'Food': u'french', u'Count': 1}, {u'Food': u'vegan', u'Count': 1}, {u'Food': u'greek', u'Count': 1}, {u'Food': u'argentinian', u'Count': 1}, {u'Food': u'vegetarian', u'Count': 1}, {u'Food': u'international', u'Count': 1}, {u'Food': u'seafood', u'Count': 1}, {u'Food': u'thai;chinese', u'Count': 1}, {u'Food': u'asian', u'Count': 1}]

# %% [markdown]
# ## Tourism  Sites

# %%
Tourism_Sites = db.St_Monica_CA.aggregate( [ 
    { "$match" : { "tourism" : { "$exists" : 1} } }, 
    { "$group" : { "_id" : "$tourism", "count" : { "$sum" : 1} } },  
    { "$sort" : { "count" : -1}},
      ])
print(list(Tourism_Sites))
# Out:
# [{u'count': 54, u'_id': u'hotel'}, {u'count': 12, u'_id': u'attraction'}, {u'count': 9, u'_id': u'motel'}, {u'count': 4, u'_id': u'museum'}, {u'count': 3, u'_id': u'picnic_site'}, {u'count': 3, u'_id': u'hostel'}, {u'count': 2, u'_id': u'artwork'}, {u'count': 1, u'_id': u'theme_park'}, {u'count': 1, u'_id': u'viewpoint'}, {u'count': 1, u'_id': u'information'}, {u'count': 1, u'_id': u'apine_hut'}]

# %% [markdown]
# ## Reference:
#
# 1.	Data design Goup.(2014).JSON : Conver XML to JSON: Retrieved from http://convertjson.com/xml-to-json.htm
# 2.	Sudirman,J.(2013). Open Street Map: Retrieved from http://napitupulu-jon.appspot.com/posts/wrangling-openstreetmap.html
# 3.	Allanbreyes.(2015). Udacity Data Science:P2: Retrieved from  https://github.com/allanbreyes/udacity-data-science/tree/master/p2
# 4.	Bogotobogo.(2016). MongoDB with Pymongo I: Retrieved from http://www.bogotobogo.com/python/MongoDB_PyMongo/python_MongoDB_pyMongo_tutorial_installing.php
# 5.	Stack over flow: Retrieved from http://stackoverflow.com/questions/2577236/regex-for-zip-code
# 6.	Regular expression101: regular expression tester : Retrieved from https://regex101.com/r/lV5yU9/1
# 7.	 MongoDB (2008). MongoDB. Retrieved from:
#   https://docs.mongodb.com/manual/reference/command/getLastError/
